# %%
#Imporatr librerías.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import datetime
import scipy.stats as ss
import sys

# %%
#Leemos cada archivo de datos y los almacenamos, cada uno, en un DataFrame. 
#Se usa Skiprows de -1 para dejar pasar un espacio y nombrar a las columnas "x" y "y".
df1 = pd.DataFrame(pd.read_csv('1wb001.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df2 = pd.DataFrame(pd.read_csv('1wb002.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df3 = pd.DataFrame(pd.read_csv('1wb003.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df4 = pd.DataFrame(pd.read_csv('1wb004.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df5 = pd.DataFrame(pd.read_csv('1wb005.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df6 = pd.DataFrame(pd.read_csv('1wb006.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df7 = pd.DataFrame(pd.read_csv('1wb007.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df8 = pd.DataFrame(pd.read_csv('1wb008.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df9 = pd.DataFrame(pd.read_csv('1wb009.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df10 = pd.DataFrame(pd.read_csv('1wb010.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df11 = pd.DataFrame(pd.read_csv('1wb011.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df12 = pd.DataFrame(pd.read_csv('1wb012.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df13 = pd.DataFrame(pd.read_csv('1wb013.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df14 = pd.DataFrame(pd.read_csv('1wb014.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df15 = pd.DataFrame(pd.read_csv('1wb015.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df16 = pd.DataFrame(pd.read_csv('1wb016.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df17 = pd.DataFrame(pd.read_csv('1wb017.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df18 = pd.DataFrame(pd.read_csv('1wb018.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df19 = pd.DataFrame(pd.read_csv('1wb019.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df20 = pd.DataFrame(pd.read_csv('1wb020.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df21 = pd.DataFrame(pd.read_csv('1wb021.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df22 = pd.DataFrame(pd.read_csv('1wb022.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df23 = pd.DataFrame(pd.read_csv('1wb023.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df24 = pd.DataFrame(pd.read_csv('1wb024.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df25 = pd.DataFrame(pd.read_csv('1wb025.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df26 = pd.DataFrame(pd.read_csv('1wb026.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df27 = pd.DataFrame(pd.read_csv('1wb027.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df28 = pd.DataFrame(pd.read_csv('1wb028.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df29 = pd.DataFrame(pd.read_csv('1wb029.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df30 = pd.DataFrame(pd.read_csv('1wb030.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df31 = pd.DataFrame(pd.read_csv('1wb031.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df32 = pd.DataFrame(pd.read_csv('1wb032.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df33 = pd.DataFrame(pd.read_csv('1wb033.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df34 = pd.DataFrame(pd.read_csv('1wb034.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df35 = pd.DataFrame(pd.read_csv('1wb035.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df36 = pd.DataFrame(pd.read_csv('1wb036.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df37 = pd.DataFrame(pd.read_csv('1wb037.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df38 = pd.DataFrame(pd.read_csv('1wb038.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df39 = pd.DataFrame(pd.read_csv('1wb039.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df40 = pd.DataFrame(pd.read_csv('1wb040.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df41 = pd.DataFrame(pd.read_csv('1wb041.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df42 = pd.DataFrame(pd.read_csv('1wb042.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df43 = pd.DataFrame(pd.read_csv('1wb043.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df44 = pd.DataFrame(pd.read_csv('1wb044.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df45 = pd.DataFrame(pd.read_csv('1wb045.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df46 = pd.DataFrame(pd.read_csv('1wb046.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df47 = pd.DataFrame(pd.read_csv('1wb047.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df48 = pd.DataFrame(pd.read_csv('1wb048.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df49 = pd.DataFrame(pd.read_csv('1wb049.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df50 = pd.DataFrame(pd.read_csv('1wb050.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df51 = pd.DataFrame( pd.read_csv("1wb051.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df52 = pd.DataFrame( pd.read_csv("1wb052.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df53 = pd.DataFrame( pd.read_csv("1wb053.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df54 = pd.DataFrame( pd.read_csv("1wb054.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df55 = pd.DataFrame( pd.read_csv("1wb055.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df56 = pd.DataFrame( pd.read_csv("1wb056.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df57 = pd.DataFrame( pd.read_csv("1wb057.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df58 = pd.DataFrame( pd.read_csv("1wb058.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df59 = pd.DataFrame( pd.read_csv("1wb059.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df60 = pd.DataFrame( pd.read_csv("1wb060.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df61 = pd.DataFrame( pd.read_csv("1wb061.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df62 = pd.DataFrame( pd.read_csv("1wb062.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df63 = pd.DataFrame( pd.read_csv("1wb063.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df64 = pd.DataFrame( pd.read_csv("1wb064.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df65 = pd.DataFrame( pd.read_csv("1wb065.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df66 = pd.DataFrame( pd.read_csv("1wb066.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df67 = pd.DataFrame( pd.read_csv("1wb067.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df68 = pd.DataFrame( pd.read_csv("1wb068.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df69 = pd.DataFrame( pd.read_csv("1wb069.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df70 = pd.DataFrame( pd.read_csv("1wb070.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df71 = pd.DataFrame( pd.read_csv("1wb071.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df72 = pd.DataFrame( pd.read_csv("1wb072.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df73 = pd.DataFrame( pd.read_csv("1wb073.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df74 = pd.DataFrame( pd.read_csv("1wb074.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df75 = pd.DataFrame( pd.read_csv("1wb075.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df76 = pd.DataFrame( pd.read_csv("1wb076.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df77 = pd.DataFrame( pd.read_csv("1wb077.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df78 = pd.DataFrame( pd.read_csv("1wb078.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df79 = pd.DataFrame( pd.read_csv("1wb079.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df80 = pd.DataFrame( pd.read_csv("1wb080.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df81 = pd.DataFrame( pd.read_csv("1wb081.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df82 = pd.DataFrame( pd.read_csv("1wb082.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df83 = pd.DataFrame( pd.read_csv("1wb083.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df84 = pd.DataFrame( pd.read_csv("1wb084.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df85 = pd.DataFrame( pd.read_csv("1wb085.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df86 = pd.DataFrame( pd.read_csv("1wb086.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df87 = pd.DataFrame( pd.read_csv("1wb087.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df88 = pd.DataFrame( pd.read_csv("1wb088.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df89 = pd.DataFrame( pd.read_csv("1wb089.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df90 = pd.DataFrame( pd.read_csv("1wb090.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df91 = pd.DataFrame( pd.read_csv("1wb091.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df92 = pd.DataFrame( pd.read_csv("1wb092.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df93 = pd.DataFrame( pd.read_csv("1wb093.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df94 = pd.DataFrame( pd.read_csv("1wb094.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df95 = pd.DataFrame( pd.read_csv("1wb095.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df96 = pd.DataFrame( pd.read_csv("1wb096.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df97 = pd.DataFrame( pd.read_csv("1wb097.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df98 = pd.DataFrame( pd.read_csv("1wb098.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df99 = pd.DataFrame( pd.read_csv("1wb099.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
df100 = pd.DataFrame( pd.read_csv("1wb100.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))

# %%
#Arreglo con los DataFrames.
dfn = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,df42,df43,df44,df45,df46,df47,df48,df49,df50,df51,df52,df53,df54,df55,df56,df57,df58,df59,df60,df61,df62,df63,df64,df65,df66,df67,df68,df69,df70,df71,df72,df73,df74,df75,df76,df77,df78,df79,df80,df81,df82,df83,df84,df85,df86,df87,df88,df89,df90,df91,df92,df93,df94,df95,df96,df97,df98,df99,df100]

# %%
#Se toma el último dato de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dfn[i].X.iloc[9999]
    y = dfn[i].Y.iloc[9999]
    datx.append(x)
    daty.append(y)
dfLast = pd.DataFrame({"X" : datx, "Y" : daty})
dfLast.index = np.arange(1, 101)
dfLast
# Out:
#          X      Y
# 1    -83.0  -95.0
# 2   -107.0   69.0
# 3     69.0   69.0
# 4   -123.0  -25.0
# 5      1.0   -1.0
# 6     81.0 -193.0
# 7    -23.0   39.0
# 8     53.0   11.0
# 9      3.0   81.0
# 10    27.0  -37.0
# 11    -7.0    7.0
# 12   209.0  -61.0
# 13    73.0   85.0
# 14   -85.0  -17.0
# 15    19.0   37.0
# 16    61.0   49.0
# 17   -35.0    5.0
# 18  -127.0   53.0
# 19  -147.0   45.0
# 20   113.0 -185.0
# 21  -103.0  -89.0
# 22  -165.0    1.0
# 23   121.0   93.0
# 24  -119.0   35.0
# 25   101.0  -89.0
# 26   -45.0  -13.0
# 27    61.0   27.0
# 28   -43.0   57.0
# 29    57.0  -29.0
# 30  -147.0   27.0
# ..     ...    ...
# 71   155.0  119.0
# 72    17.0  -15.0
# 73   -71.0  -99.0
# 74    15.0   97.0
# 75    85.0  121.0
# 76   -41.0  -29.0
# 77   159.0  -55.0
# 78   225.0  167.0
# 79   -99.0  231.0
# 80    -5.0   59.0
# 81   -13.0  -89.0
# 82    29.0  -43.0
# 83   113.0   55.0
# 84  -305.0  -91.0
# 85   -43.0   93.0
# 86   131.0  117.0
# 87    79.0  -11.0
# 88    71.0   17.0
# ...

# %%
#Descripción de datos.
dfLast.describe()
# Out:
#                X           Y
# count  100.00000  100.000000
# mean    -0.22000   10.200000
# std    107.60943   93.259278
# min   -305.00000 -253.000000
# 25%    -72.00000  -37.500000
# 50%      5.00000   16.000000
# 75%     76.00000   73.000000
# max    227.00000  231.000000

# %%
#Boxplot para los últimos datos.
dfLast.plot.box(grid=True,color='b')

# %%
#Se verifican los tipos de datos (que sean float64).
dfLast.dtypes
# Out:
# X    float64
# Y    float64
# dtype: object

# %%
#Promedio en "X" y "Y".
mediax = dfLast["X"].mean()
mediay = dfLast["Y"].mean()

# %%
mediax
# Out:
# -0.22

# %%
mediay
# Out:
# 10.2

# %%
#Desviación Estándar en "X" y "Y".
sdx = dfLast["X"].std()
sdy = dfLast["Y"].std()

# %%
sdx
# Out:
# 107.60943032536456

# %%
sdy
# Out:
# 93.25927797968913

# %%
#Arreglos para medias y desviaciones
MediasObs = [mediax, mediay]
DesvObs = [sdx, sdy]

# %%
#Histograma con "bins" columnas.
hist = dfLast.hist(bins=40)

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfLast
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.988, p=0.077
# La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)

# %%
#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasY, DesvY = ss.norm.fit(dfLast["Y"])
print("Media ajustada a la normal =", MediasY)
print("Desviación ajustada a la normal =", DesvY)
print("Media observada =", mediay)
print("Desviación observada =", sdy)
# Out:
# Media ajustada a la normal = 10.2
# Desviación ajustada a la normal = 92.79180998342473
# Media observada = 10.2
# Desviación observada = 93.25927797968913

# %%
#Se hace un ajuste para aproximar a una Normal para las "X".
MediasX, DesvX = ss.norm.fit(dfLast["X"])
print("Media ajustada a la normal =", MediasX)
print("Desviación ajustada a la normal =", DesvX)
print("Media observada =", mediax)
print("Desviación observada =", sdx)
# Out:
# Media ajustada a la normal = -0.22
# Desviación ajustada a la normal = 107.07003128793788
# Media observada = -0.22
# Desviación observada = 107.60943032536456

# %% [markdown]
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# Se analizarán, de las 100 trayectorias de partículas, el paso 100.

# %%
#Se toma el dato 100 de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dfn[i].X.iloc[100]
    y = dfn[i].Y.iloc[100]
    datx.append(x)
    daty.append(y)
dfCien = pd.DataFrame({"X" : datx, "Y" : daty})
dfCien.index = np.arange(1, 101)
dfCien
# Out:
#         X     Y
# 1    -8.0  -4.0
# 2    -6.0   2.0
# 3   -14.0  28.0
# 4     8.0   0.0
# 5    14.0  18.0
# 6     4.0   0.0
# 7    16.0  16.0
# 8   -14.0  24.0
# 9     2.0 -12.0
# 10    8.0 -12.0
# 11  -14.0   6.0
# 12   12.0  -8.0
# 13   16.0   0.0
# 14   14.0 -12.0
# 15   -4.0  18.0
# 16   -8.0 -14.0
# 17    4.0   6.0
# 18  -28.0  -6.0
# 19   -8.0 -16.0
# 20   -6.0  10.0
# 21   12.0  -8.0
# 22   -6.0  18.0
# 23  -12.0  -4.0
# 24   -2.0  -4.0
# 25   12.0  14.0
# 26    0.0  20.0
# 27   10.0   4.0
# 28   -6.0   4.0
# 29    4.0 -16.0
# 30    8.0  -2.0
# ..    ...   ...
# 71   -4.0   0.0
# 72   16.0   8.0
# 73   -8.0   2.0
# 74  -14.0 -22.0
# 75   -2.0   4.0
# 76  -10.0   8.0
# 77   18.0  -2.0
# 78    4.0   2.0
# 79    0.0  -2.0
# 80   -4.0 -10.0
# 81    6.0 -14.0
# 82   -6.0 -12.0
# 83   -2.0  -8.0
# 84  -20.0 -14.0
# 85   -6.0  10.0
# 86    4.0   2.0
# 87  -10.0  -8.0
# 88  -12.0  -2.0
# 89   -8.0  -4.0
# 90   -6.0 -22.0
# 91    8.0  -4.0
# 92  -10.0   0.0
# 93   -8.0  -2.0
# ...

# %%
#Descripción de datos.
dfCien.describe()
# Out:
#                 X          Y
# count  100.000000  100.00000
# mean    -1.220000    0.60000
# std      9.920472   10.34945
# min    -28.000000  -22.00000
# 25%     -8.000000   -6.00000
# 50%     -2.000000    0.00000
# 75%      4.000000    6.50000
# max     20.000000   28.00000

# %%
#Boxplot para los 100° datos.
dfCien.plot.box(grid=True, color='b')

# %%
#Se verifican los tipos de datos (que sean float64).
dfCien.dtypes
# Out:
# X    float64
# Y    float64
# dtype: object

# %%
#Promedio en "X" y "Y".
mediax = dfCien["X"].mean()
mediay = dfCien["Y"].mean()

# %%
mediax
# Out:
# -1.22

# %%
mediay
# Out:
# 0.6

# %%
#Desviación Estándar en "X" y "Y".
sdx = dfCien["X"].std()
sdy = dfCien["Y"].std()

# %%
sdx
# Out:
# 9.920471640791966

# %%
sdy
# Out:
# 10.349449797506683

# %%
#Arreglos para medias y desviaciones
MediasObs = [mediax, mediay]
DesvObs = [sdx, sdy]

# %%
#Histograma con "bins" columnas.
hist = dfCien.hist(bins=40)

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfCien
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.989, p=0.108
# La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)

# %%
#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasY, DesvY = ss.norm.fit(dfCien["Y"])
print("Media ajustada a la normal =", MediasY)
print("Desviación ajustada a la normal =", DesvY)
print("Media observada =", mediay)
print("Desviación observada =", sdy)
# Out:
# Media ajustada a la normal = 0.6
# Desviación ajustada a la normal = 10.2975725294848
# Media observada = 0.6
# Desviación observada = 10.349449797506683

# %%
#Se hace un ajuste para aproximar a una Normal para las "X".
MediasX, DesvX = ss.norm.fit(dfCien["X"])
print("Media ajustada a la normal =", MediasX)
print("Desviación ajustada a la normal =", DesvX)
print("Media observada =", mediax)
print("Desviación observada =", sdx)
# Out:
# Media ajustada a la normal = -1.22
# Desviación ajustada a la normal = 9.8707446527605
# Media observada = -1.22
# Desviación observada = 9.920471640791966

# %%
#Graficamos la trayectoria de la partícula 1wb002
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(df2["X"], df2["Y"],label='x', marker=".")
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1wb032
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(df32["X"], df32["Y"],label='x', marker=".")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1wb072
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(df72["X"], df72["Y"], label='x', marker=".")
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1wb078
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(df78["X"], df78["Y"], label='x', marker=".")
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de 50 partículas 
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(df50["X"], df50["Y"], marker=".")
plt.plot(df51["X"], df51["Y"], marker=".")
plt.plot(df52["X"], df52["Y"], marker=".")
plt.plot(df53["X"], df53["Y"], marker=".")
plt.plot(df54["X"], df54["Y"], marker=".")
plt.plot(df55["X"], df55["Y"], marker=".")
plt.plot(df56["X"], df56["Y"], marker=".")
plt.plot(df57["X"], df57["Y"], marker=".")
plt.plot(df58["X"], df58["Y"], marker=".")
plt.plot(df59["X"], df59["Y"], marker=".")
plt.plot(df60["X"], df60["Y"], marker=".")
plt.plot(df61["X"], df61["Y"], marker=".")
plt.plot(df62["X"], df62["Y"], marker=".")
plt.plot(df63["X"], df63["Y"], marker=".")
plt.plot(df64["X"], df64["Y"], marker=".")
plt.plot(df65["X"], df65["Y"], marker=".")
plt.plot(df66["X"], df66["Y"], marker=".")
plt.plot(df67["X"], df67["Y"], marker=".")
plt.plot(df68["X"], df68["Y"], marker=".")
plt.plot(df69["X"], df69["Y"], marker=".")
plt.plot(df70["X"], df70["Y"], marker=".")
plt.plot(df71["X"], df71["Y"], marker=".")
plt.plot(df72["X"], df72["Y"], marker=".")
plt.plot(df73["X"], df73["Y"], marker=".")
plt.plot(df74["X"], df74["Y"], marker=".")
plt.plot(df75["X"], df75["Y"], marker=".")
plt.plot(df76["X"], df76["Y"], marker=".")
plt.plot(df77["X"], df77["Y"], marker=".")
plt.plot(df78["X"], df78["Y"], marker=".")
plt.plot(df79["X"], df79["Y"], marker=".")
plt.plot(df80["X"], df80["Y"], marker=".")
plt.plot(df81["X"], df81["Y"], marker=".")
plt.plot(df82["X"], df82["Y"], marker=".")
plt.plot(df83["X"], df83["Y"], marker=".")
plt.plot(df84["X"], df84["Y"], marker=".")
plt.plot(df85["X"], df85["Y"], marker=".")
plt.plot(df86["X"], df86["Y"], marker=".")
plt.plot(df87["X"], df87["Y"], marker=".")
plt.plot(df88["X"], df88["Y"], marker=".")
plt.plot(df89["X"], df89["Y"], marker=".")
plt.plot(df90["X"], df90["Y"], marker=".")
plt.plot(df91["X"], df91["Y"], marker=".")
plt.plot(df92["X"], df92["Y"], marker=".")
plt.plot(df93["X"], df93["Y"], marker=".")
plt.plot(df94["X"], df94["Y"], marker=".")
plt.plot(df95["X"], df95["Y"], marker=".")
plt.plot(df96["X"], df96["Y"], marker=".")
plt.plot(df97["X"], df97["Y"], marker=".")
plt.plot(df98["X"], df98["Y"], marker=".")
plt.plot(df99["X"], df99["Y"], marker=".")
plt.plot(df100["X"], df100["Y"], marker=".")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %% [markdown]
# Ahora se analizará la manera de decidir la probabilidad de tomar un paso a la derecha o izquierda (en las posiciones en X), o un paso hacia arriba o abajo (en las posiciones en Y).
# Los archivos utilizados para ello contienen dos columnas, cada una con una secuencia de números aleatorios con distribución uniforme.
# En base a estos números aleatorios con distribución uniforme, se decidieron las probabilidades (0.5 a cada lado, tanto en X y Y). Debido a que la distribución es uniforme, cada vez que se decidió un paso de la partícula, se llamó a un número aleatorio NAX para su movimiento en X, y otro número aleatorio NAY para su movimiento en Y.
#
# En X se toman valores entre 0 y 1.
#    - Si NAX < 0.5, se desplaza a la derecha.
#    - Si NAX > 0.5, se desplaza a la izquierda.
#
# En Y se toman valores entre 0 y 1.
#    - Si NAY < 0.5, se desplaza hacia arriba.
#    - Si NAY > 0.5, se desplaza hacia abbajo.
#
# Esto debe ser consistente con el Teorema del Límite Central, ya que la probabilidad de que la partícula, después de una gran cantidad de pasos, esté a determinados pasos de su origen, debe corresponder a una distribución Gaussiana (Observado en los histogramas anteriores).

# %%
#Leemos los archivos de 10,000 números aleatorios. 
#Se usa Skiprows de -1 para dejar pasar un espacio y nombrar a las columnas "NAX" (Número Aleatorio en X) y 
#"NAY" (Número Aleatorio en Y).
#Se lee el archivo con 10,000 parejas de datos aleatorios.
dfRand10000 = pd.DataFrame(pd.read_csv('nale10000.dat', skiprows=-1, sep='\s+', header=None, names = ["NAX", "NAY"]))
dfRand10000.index = np.arange(1, 10000)
dfRand10000.head()
# Out:
#         NAX       NAY
# 1  0.007042  0.997472
# 2  0.724573  0.601291
# 3  0.130247  0.289472
# 4  0.260807  0.451975
# 5  0.937638  0.471129

# %%
#Como se trata de una distribución uniforme, un gráfica del DataFrame debería tener puntos distribuídos
#uniformemente enel rango de 0 a 1 para X y de 0.5 a 1 para Y.
#Graficamos las parejas de datos aleatorios.
plt.figure(figsize=(7, 7))
#Marcamos la trayectoria con puntos.
plt.plot(dfRand10000["NAX"], dfRand10000["NAY"], 'mo')
plt.grid(True)
#plt.legend()
plt.title("NAX vs. NAY")
plt.show()

# %% [markdown]
# Se puede observar que existen la misma cantidad de puntos en cada uno, por lo que sería correcto inferir que se tiene la misma probabilidad de ir a un lado u otro, o arriba o abajo , es decr, que el movimiento en X o en Y no está favorecido en alguna dirección.

# %%
#Leemos los archivos de 100 números aleatorios. 
#Se usa Skiprows de -1 para dejar pasar un espacio y nombrar a las columnas "NAX" (Número Aleatorio en X) y 
#"NAY" (Número Aleatorio en Y).
#Se lee el archivo con 10,000 parejas de datos aleatorios.
dfRand100 = pd.DataFrame(pd.read_csv('nale100.dat', skiprows=-1, sep='\s+', header=None, names = ["NAX", "NAY"]))
dfRand100.index = np.arange(1, 100)
#Graficamos las parejas de datos aleatorios.
plt.figure(figsize=(7, 7))
#Marcamos la trayectoria con puntos.
plt.plot(dfRand100["NAX"], dfRand100["NAY"], 'mo')
plt.grid(True)
#plt.legend()
plt.title("NAX vs. NAY")
plt.show()

# %%
#Leemos los archivos de 1,000 números aleatorios. 
#Se usa Skiprows de -1 para dejar pasar un espacio y nombrar a las columnas "NAX" (Número Aleatorio en X) y 
#"NAY" (Número Aleatorio en Y).
#Se lee el archivo con 10,000 parejas de datos aleatorios.
dfRand1000 = pd.DataFrame(pd.read_csv('nale1000.dat', skiprows=-1, sep='\s+', header=None, names = ["NAX", "NAY"]))
dfRand1000.index = np.arange(1, 1000)
#Graficamos las parejas de datos aleatorios.
plt.figure(figsize=(7, 7))
#Marcamos la trayectoria con puntos.
plt.plot(dfRand1000["NAX"], dfRand1000["NAY"], 'mo')
plt.grid(True)
#plt.legend()
plt.title("NAX vs. NAY")
plt.show()

# %%
#Leemos los archivos de 100,000 números aleatorios. 
#Se usa Skiprows de -1 para dejar pasar un espacio y nombrar a las columnas "NAX" (Número Aleatorio en X) y 
#"NAY" (Número Aleatorio en Y).
#Se lee el archivo con 10,000 parejas de datos aleatorios.
dfRand100000 = pd.DataFrame(pd.read_csv('nale100000.dat', skiprows=-1, sep='\s+', header=None, names = ["NAX", "NAY"]))
dfRand100000.index = np.arange(1, 100000)
#Graficamos las parejas de datos aleatorios.
plt.figure(figsize=(7, 7))
#Marcamos la trayectoria con puntos.
plt.plot(dfRand100000["NAX"], dfRand100000["NAY"], 'mo')
plt.grid(True)
#plt.legend()
plt.title("NAX vs. NAY")
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Ahora se analizarán los casos donde haya un lado más favorecido.
#
# **PROBABILIDAD PASO A LA DERECHA EN X de 0.55 y PASO HACIA ARRIBA EN Y de 0.55**

# %%
#Leemos los archivos de datos
dfe1 = pd.DataFrame(pd.read_csv('1we001.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe2 = pd.DataFrame(pd.read_csv('1we002.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe3 = pd.DataFrame(pd.read_csv('1we003.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe4 = pd.DataFrame(pd.read_csv('1we004.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe5 = pd.DataFrame(pd.read_csv('1we005.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe6 = pd.DataFrame(pd.read_csv('1we006.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe7 = pd.DataFrame(pd.read_csv('1we007.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe8 = pd.DataFrame(pd.read_csv('1we008.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe9 = pd.DataFrame(pd.read_csv('1we009.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe10 = pd.DataFrame(pd.read_csv('1we010.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe11 = pd.DataFrame(pd.read_csv('1we011.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe12 = pd.DataFrame(pd.read_csv('1we012.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe13 = pd.DataFrame(pd.read_csv('1we013.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe14 = pd.DataFrame(pd.read_csv('1we014.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe15 = pd.DataFrame(pd.read_csv('1we015.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe16 = pd.DataFrame(pd.read_csv('1we016.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe17 = pd.DataFrame(pd.read_csv('1we017.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe18 = pd.DataFrame(pd.read_csv('1we018.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe19 = pd.DataFrame(pd.read_csv('1we019.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe20 = pd.DataFrame(pd.read_csv('1we020.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe21 = pd.DataFrame(pd.read_csv('1we021.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe22 = pd.DataFrame(pd.read_csv('1we022.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe23 = pd.DataFrame(pd.read_csv('1we023.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe24 = pd.DataFrame(pd.read_csv('1we024.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe25 = pd.DataFrame(pd.read_csv('1we025.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe26 = pd.DataFrame(pd.read_csv('1we026.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe27 = pd.DataFrame(pd.read_csv('1we027.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe28 = pd.DataFrame(pd.read_csv('1we028.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe29 = pd.DataFrame(pd.read_csv('1we029.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe30 = pd.DataFrame(pd.read_csv('1we030.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe31 = pd.DataFrame(pd.read_csv('1we031.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe32 = pd.DataFrame(pd.read_csv('1we032.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe33 = pd.DataFrame(pd.read_csv('1we033.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe34 = pd.DataFrame(pd.read_csv('1we034.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe35 = pd.DataFrame(pd.read_csv('1we035.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe36 = pd.DataFrame(pd.read_csv('1we036.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe37 = pd.DataFrame(pd.read_csv('1we037.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe38 = pd.DataFrame(pd.read_csv('1we038.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe39 = pd.DataFrame(pd.read_csv('1we039.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe40 = pd.DataFrame(pd.read_csv('1we040.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe41 = pd.DataFrame(pd.read_csv('1we041.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe42 = pd.DataFrame(pd.read_csv('1we042.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe43 = pd.DataFrame(pd.read_csv('1we043.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe44 = pd.DataFrame(pd.read_csv('1we044.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe45 = pd.DataFrame(pd.read_csv('1we045.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe46 = pd.DataFrame(pd.read_csv('1we046.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe47 = pd.DataFrame(pd.read_csv('1we047.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe48 = pd.DataFrame(pd.read_csv('1we048.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe49 = pd.DataFrame(pd.read_csv('1we049.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe50 = pd.DataFrame(pd.read_csv('1we050.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe51 = pd.DataFrame( pd.read_csv("1we051.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe52 = pd.DataFrame( pd.read_csv("1we052.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe53 = pd.DataFrame( pd.read_csv("1we053.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe54 = pd.DataFrame( pd.read_csv("1we054.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe55 = pd.DataFrame( pd.read_csv("1we055.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe56 = pd.DataFrame( pd.read_csv("1we056.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe57 = pd.DataFrame( pd.read_csv("1we057.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe58 = pd.DataFrame( pd.read_csv("1we058.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe59 = pd.DataFrame( pd.read_csv("1we059.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe60 = pd.DataFrame( pd.read_csv("1we060.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe61 = pd.DataFrame( pd.read_csv("1we061.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe62 = pd.DataFrame( pd.read_csv("1we062.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe63 = pd.DataFrame( pd.read_csv("1we063.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe64 = pd.DataFrame( pd.read_csv("1we064.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe65 = pd.DataFrame( pd.read_csv("1we065.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe66 = pd.DataFrame( pd.read_csv("1we066.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe67 = pd.DataFrame( pd.read_csv("1we067.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe68 = pd.DataFrame( pd.read_csv("1we068.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe69 = pd.DataFrame( pd.read_csv("1we069.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe70 = pd.DataFrame( pd.read_csv("1we070.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe71 = pd.DataFrame( pd.read_csv("1we071.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe72 = pd.DataFrame( pd.read_csv("1we072.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe73 = pd.DataFrame( pd.read_csv("1we073.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe74 = pd.DataFrame( pd.read_csv("1we074.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe75 = pd.DataFrame( pd.read_csv("1we075.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe76 = pd.DataFrame( pd.read_csv("1we076.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe77 = pd.DataFrame( pd.read_csv("1we077.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe78 = pd.DataFrame( pd.read_csv("1we078.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe79 = pd.DataFrame( pd.read_csv("1we079.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe80 = pd.DataFrame( pd.read_csv("1we080.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe81 = pd.DataFrame( pd.read_csv("1we081.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe82 = pd.DataFrame( pd.read_csv("1we082.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe83 = pd.DataFrame( pd.read_csv("1we083.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe84 = pd.DataFrame( pd.read_csv("1we084.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe85 = pd.DataFrame( pd.read_csv("1we085.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe86 = pd.DataFrame( pd.read_csv("1we086.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe87 = pd.DataFrame( pd.read_csv("1we087.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe88 = pd.DataFrame( pd.read_csv("1we088.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe89 = pd.DataFrame( pd.read_csv("1we089.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe90 = pd.DataFrame( pd.read_csv("1we090.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe91 = pd.DataFrame( pd.read_csv("1we091.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe92 = pd.DataFrame( pd.read_csv("1we092.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe93 = pd.DataFrame( pd.read_csv("1we093.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe94 = pd.DataFrame( pd.read_csv("1we094.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe95 = pd.DataFrame( pd.read_csv("1we095.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe96 = pd.DataFrame( pd.read_csv("1we096.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe97 = pd.DataFrame( pd.read_csv("1we097.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe98 = pd.DataFrame( pd.read_csv("1we098.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe99 = pd.DataFrame( pd.read_csv("1we099.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfe100 = pd.DataFrame( pd.read_csv("1we100.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))

# %%
#Arreglo de los DataFrames
dfen = [dfe1,dfe2,dfe3,dfe4,dfe5,dfe6,dfe7,dfe8,dfe9,dfe10,dfe11,dfe12,dfe13,dfe14,dfe15,dfe16,dfe17,dfe18,dfe19,dfe20,dfe21,dfe22,dfe23,dfe24,dfe25,dfe26,dfe27,dfe28,dfe29,dfe30,dfe31,dfe32,dfe33,dfe34,dfe35,dfe36,dfe37,dfe38,dfe39,dfe40,dfe41,dfe42,dfe43,dfe44,dfe45,dfe46,dfe47,dfe48,dfe49,dfe50,dfe51,dfe52,dfe53,dfe54,dfe55,dfe56,dfe57,dfe58,dfe59,dfe60,dfe61,dfe62,dfe63,dfe64,dfe65,dfe66,dfe67,dfe68,dfe69,dfe70,dfe71,dfe72,dfe73,dfe74,dfe75,dfe76,dfe77,dfe78,dfe79,dfe80,dfe81,dfe82,dfe83,dfe84,dfe85,dfe86,dfe87,dfe88,dfe89,dfe90,dfe91,dfe92,dfe93,dfe94,dfe95,dfe96,dfe97,dfe98,dfe99,dfe100]

# %%
#Se toma el último dato de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dfen[i].X.iloc[9999]
    y = dfen[i].Y.iloc[9999]
    datx.append(x)
    daty.append(y)
dfeLast = pd.DataFrame({"X" : datx, "Y" : daty})
dfeLast.index = np.arange(1, 101)
dfeLast
# Out:
#           X       Y
# 1     901.0  1037.0
# 2     901.0  1001.0
# 3     927.0  1061.0
# 4    1037.0   851.0
# 5     999.0  1067.0
# 6    1143.0  1043.0
# 7    1135.0  1013.0
# 8     987.0  1109.0
# 9    1001.0   873.0
# 10    947.0  1009.0
# 11   1121.0  1041.0
# 12   1051.0   989.0
# 13   1145.0   955.0
# 14   1021.0   947.0
# 15   1129.0  1069.0
# 16    977.0   903.0
# 17    873.0  1077.0
# 18   1087.0  1073.0
# 19   1001.0   955.0
# 20   1169.0  1011.0
# 21    907.0   895.0
# 22    975.0  1099.0
# 23    993.0   917.0
# 24    983.0   927.0
# 25    981.0   899.0
# 26   1203.0  1089.0
# 27   1059.0   975.0
# 28    917.0   999.0
# 29    799.0   765.0
# 30    845.0   817.0
# ..      ...     ...
# 71    895.0  1029.0
# 72   1097.0   791.0
# 73   1025.0   941.0
# 74    969.0   959.0
# 75   1047.0   851.0
# 76   1085.0   949.0
# 77   1083.0  1035.0
# 78   1023.0  1069.0
# 79    851.0   935.0
# 80   1023.0   889.0
# 81   1189.0  1007.0
# 82    867.0  1061.0
# 83    999.0   855.0
# ...

# %%
#Descripción de datos.
dfeLast.describe()
# Out:
#                  X            Y
# count   100.000000   100.000000
# mean   1003.960000  1002.240000
# std     107.312243    91.431171
# min     675.000000   765.000000
# 25%     940.000000   948.500000
# 50%    1001.000000  1014.000000
# 75%    1071.000000  1064.000000
# max    1269.000000  1199.000000

# %%
#Boxplot para los últimos datos.
dfeLast.plot.box(grid=True,color='brown')

# %%
#Histograma con "bins" columnas.
hist = dfeLast.hist(bins=40, color='brown')

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfeLast
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.993, p=0.495
# La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)

# %%
#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasX, DesvX = ss.norm.fit(dfeLast["X"])
print("Media ajustada a la normal =", MediasX)
print("Desviación ajustada a la normal =", DesvX)

#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasY, DesvY = ss.norm.fit(dfeLast["Y"])
print("Media ajustada a la normal =", MediasY)
print("Desviación ajustada a la normal =", DesvY)
# Out:
# Media ajustada a la normal = 1003.96
# Desviación ajustada a la normal = 106.77433399464498
# Media ajustada a la normal = 1002.24
# Desviación ajustada a la normal = 90.97286628440374

# %% [markdown]
# Se evalúa lo mismo con el dato número 100 de cada partícula.

# %%
#Se toma el dato 100 de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dfen[i].X.iloc[100]
    y = dfen[i].Y.iloc[100]
    datx.append(x)
    daty.append(y)
dfeCien = pd.DataFrame({"X" : datx, "Y" : daty})
dfeCien.index = np.arange(1, 101)
dfeCien
# Out:
#         X     Y
# 1    18.0  16.0
# 2    20.0  24.0
# 3     8.0   8.0
# 4    10.0  18.0
# 5    12.0  10.0
# 6    -6.0  -2.0
# 7    10.0  28.0
# 8    12.0   8.0
# 9    14.0  -4.0
# 10   24.0  12.0
# 11    4.0   2.0
# 12   10.0  -6.0
# 13   22.0   2.0
# 14   12.0   6.0
# 15   14.0  10.0
# 16    4.0   2.0
# 17    4.0  18.0
# 18   10.0  22.0
# 19    2.0  16.0
# 20   16.0  24.0
# 21    4.0   4.0
# 22    6.0   4.0
# 23   10.0  -2.0
# 24   30.0  18.0
# 25    6.0   0.0
# 26   32.0  30.0
# 27   10.0  -6.0
# 28   26.0   6.0
# 29    4.0   0.0
# 30   -2.0   8.0
# ..    ...   ...
# 71   -6.0  -4.0
# 72   18.0  16.0
# 73   14.0   0.0
# 74   28.0  30.0
# 75   12.0  18.0
# 76   -2.0  20.0
# 77   24.0   4.0
# 78    0.0  20.0
# 79   10.0  -6.0
# 80   28.0   2.0
# 81   14.0  14.0
# 82    6.0  30.0
# 83    0.0 -16.0
# 84   38.0   4.0
# 85    2.0  -8.0
# 86   10.0  10.0
# 87    4.0  20.0
# 88   22.0   4.0
# 89   16.0  18.0
# 90   26.0   0.0
# 91   16.0   8.0
# 92   14.0  18.0
# 93    4.0  26.0
# ...

# %%
#Descripción de datos.
dfeCien.describe()
# Out:
#                 X           Y
# count  100.000000  100.000000
# mean    10.820000    9.900000
# std     10.078861   10.111999
# min     -8.000000  -16.000000
# 25%      4.000000    2.000000
# 50%     11.000000   10.000000
# 75%     16.000000   18.000000
# max     38.000000   34.000000

# %%
#Boxplot para los 100° datos.
dfeCien.plot.box(grid=True,color='brown')

# %%
#Histograma con "bins" columnas.
hist = dfeCien.hist(bins=30, color='brown')

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfeCien
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.987, p=0.067
# La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)

# %%
#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasX, DesvX = ss.norm.fit(dfeCien["X"])
print("Media ajustada a la normal =", MediasX)
print("Desviación ajustada a la normal =", DesvX)

#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasY, DesvY = ss.norm.fit(dfeCien["Y"])
print("Media ajustada a la normal =", MediasY)
print("Desviación ajustada a la normal =", DesvY)
# Out:
# Media ajustada a la normal = 10.82
# Desviación ajustada a la normal = 10.028339842665883
# Media ajustada a la normal = 9.9
# Desviación ajustada a la normal = 10.061312041677269

# %%
#Graficamos la trayectoria de la partícula 1we002
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfe2["X"], dfe2["Y"], label='x', marker=".", color='brown')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1we072
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfe72["X"], dfe72["Y"], label='x', marker=".", color='brown')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1we056
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfe56["X"], dfe56["Y"], label='x', marker=".", color='brown')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1we049
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfe49["X"], dfe49["Y"], label='x', marker=".", color='brown')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de 50 partículas 
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfe50["X"], dfe50["Y"], marker=".")
plt.plot(dfe51["X"], dfe51["Y"], marker=".")
plt.plot(dfe52["X"], dfe52["Y"], marker=".")
plt.plot(dfe53["X"], dfe53["Y"], marker=".")
plt.plot(dfe54["X"], dfe54["Y"], marker=".")
plt.plot(dfe55["X"], dfe55["Y"], marker=".")
plt.plot(dfe56["X"], dfe56["Y"], marker=".")
plt.plot(dfe57["X"], dfe57["Y"], marker=".")
plt.plot(dfe58["X"], dfe58["Y"], marker=".")
plt.plot(dfe59["X"], dfe59["Y"], marker=".")
plt.plot(dfe60["X"], dfe60["Y"], marker=".")
plt.plot(dfe61["X"], dfe61["Y"], marker=".")
plt.plot(dfe62["X"], dfe62["Y"], marker=".")
plt.plot(dfe63["X"], dfe63["Y"], marker=".")
plt.plot(dfe64["X"], dfe64["Y"], marker=".")
plt.plot(dfe65["X"], dfe65["Y"], marker=".")
plt.plot(dfe66["X"], dfe66["Y"], marker=".")
plt.plot(dfe67["X"], dfe67["Y"], marker=".")
plt.plot(dfe68["X"], dfe68["Y"], marker=".")
plt.plot(dfe69["X"], dfe69["Y"], marker=".")
plt.plot(dfe70["X"], dfe70["Y"], marker=".")
plt.plot(dfe71["X"], dfe71["Y"], marker=".")
plt.plot(dfe72["X"], dfe72["Y"], marker=".")
plt.plot(dfe73["X"], dfe73["Y"], marker=".")
plt.plot(dfe74["X"], dfe74["Y"], marker=".")
plt.plot(dfe75["X"], dfe75["Y"], marker=".")
plt.plot(dfe76["X"], dfe76["Y"], marker=".")
plt.plot(dfe77["X"], dfe77["Y"], marker=".")
plt.plot(dfe78["X"], dfe78["Y"], marker=".")
plt.plot(dfe79["X"], dfe79["Y"], marker=".")
plt.plot(dfe80["X"], dfe80["Y"], marker=".")
plt.plot(dfe81["X"], dfe81["Y"], marker=".")
plt.plot(dfe82["X"], dfe82["Y"], marker=".")
plt.plot(dfe83["X"], dfe83["Y"], marker=".")
plt.plot(dfe84["X"], dfe84["Y"], marker=".")
plt.plot(dfe85["X"], dfe85["Y"], marker=".")
plt.plot(dfe86["X"], dfe86["Y"], marker=".")
plt.plot(dfe87["X"], dfe87["Y"], marker=".")
plt.plot(dfe88["X"], dfe88["Y"], marker=".")
plt.plot(dfe89["X"], dfe89["Y"], marker=".")
plt.plot(dfe90["X"], dfe90["Y"], marker=".")
plt.plot(dfe91["X"], dfe91["Y"], marker=".")
plt.plot(dfe92["X"], dfe92["Y"], marker=".")
plt.plot(dfe93["X"], dfe93["Y"], marker=".")
plt.plot(dfe94["X"], dfe94["Y"], marker=".")
plt.plot(dfe95["X"], dfe95["Y"], marker=".")
plt.plot(dfe96["X"], dfe96["Y"], marker=".")
plt.plot(dfe97["X"], dfe97["Y"], marker=".")
plt.plot(dfe98["X"], dfe98["Y"], marker=".")
plt.plot(dfe99["X"], dfe99["Y"], marker=".")
plt.plot(dfe100["X"], dfe100["Y"], marker=".")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **PROBABILIDAD PASO A LA DERECHA EN X DE 0.60 y en Y DE 0.50**

# %%
#Se leen los archivos de datos.
#Se usa Skiprows de -1 para dejar pasar un espacio y nombrar a las columnas "x" y "y".
dfd1 = pd.DataFrame(pd.read_csv('1wd001.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd2 = pd.DataFrame(pd.read_csv('1wd002.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd3 = pd.DataFrame(pd.read_csv('1wd003.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd4 = pd.DataFrame(pd.read_csv('1wd004.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd5 = pd.DataFrame(pd.read_csv('1wd005.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd6 = pd.DataFrame(pd.read_csv('1wd006.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd7 = pd.DataFrame(pd.read_csv('1wd007.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd8 = pd.DataFrame(pd.read_csv('1wd008.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd9 = pd.DataFrame(pd.read_csv('1wd009.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd10 = pd.DataFrame(pd.read_csv('1wd010.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd11 = pd.DataFrame(pd.read_csv('1wd011.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd12 = pd.DataFrame(pd.read_csv('1wd012.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd13 = pd.DataFrame(pd.read_csv('1wd013.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd14 = pd.DataFrame(pd.read_csv('1wd014.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd15 = pd.DataFrame(pd.read_csv('1wd015.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd16 = pd.DataFrame(pd.read_csv('1wd016.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd17 = pd.DataFrame(pd.read_csv('1wd017.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd18 = pd.DataFrame(pd.read_csv('1wd018.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd19 = pd.DataFrame(pd.read_csv('1wd019.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd20 = pd.DataFrame(pd.read_csv('1wd020.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd21 = pd.DataFrame(pd.read_csv('1wd021.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd22 = pd.DataFrame(pd.read_csv('1wd022.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd23 = pd.DataFrame(pd.read_csv('1wd023.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd24 = pd.DataFrame(pd.read_csv('1wd024.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd25 = pd.DataFrame(pd.read_csv('1wd025.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd26 = pd.DataFrame(pd.read_csv('1wd026.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd27 = pd.DataFrame(pd.read_csv('1wd027.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd28 = pd.DataFrame(pd.read_csv('1wd028.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd29 = pd.DataFrame(pd.read_csv('1wd029.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd30 = pd.DataFrame(pd.read_csv('1wd030.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd31 = pd.DataFrame(pd.read_csv('1wd031.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd32 = pd.DataFrame(pd.read_csv('1wd032.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd33 = pd.DataFrame(pd.read_csv('1wd033.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd34 = pd.DataFrame(pd.read_csv('1wd034.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd35 = pd.DataFrame(pd.read_csv('1wd035.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd36 = pd.DataFrame(pd.read_csv('1wd036.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd37 = pd.DataFrame(pd.read_csv('1wd037.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd38 = pd.DataFrame(pd.read_csv('1wd038.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd39 = pd.DataFrame(pd.read_csv('1wd039.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd40 = pd.DataFrame(pd.read_csv('1wd040.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd41 = pd.DataFrame(pd.read_csv('1wd041.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd42 = pd.DataFrame(pd.read_csv('1wd042.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd43 = pd.DataFrame(pd.read_csv('1wd043.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd44 = pd.DataFrame(pd.read_csv('1wd044.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd45 = pd.DataFrame(pd.read_csv('1wd045.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd46 = pd.DataFrame(pd.read_csv('1wd046.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd47 = pd.DataFrame(pd.read_csv('1wd047.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd48 = pd.DataFrame(pd.read_csv('1wd048.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd49 = pd.DataFrame(pd.read_csv('1wd049.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd50 = pd.DataFrame(pd.read_csv('1wd050.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd51 = pd.DataFrame( pd.read_csv("1wd051.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd52 = pd.DataFrame( pd.read_csv("1wd052.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd53 = pd.DataFrame( pd.read_csv("1wd053.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd54 = pd.DataFrame( pd.read_csv("1wd054.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd55 = pd.DataFrame( pd.read_csv("1wd055.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd56 = pd.DataFrame( pd.read_csv("1wd056.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd57 = pd.DataFrame( pd.read_csv("1wd057.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd58 = pd.DataFrame( pd.read_csv("1wd058.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd59 = pd.DataFrame( pd.read_csv("1wd059.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd60 = pd.DataFrame( pd.read_csv("1wd060.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd61 = pd.DataFrame( pd.read_csv("1wd061.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd62 = pd.DataFrame( pd.read_csv("1wd062.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd63 = pd.DataFrame( pd.read_csv("1wd063.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd64 = pd.DataFrame( pd.read_csv("1wd064.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd65 = pd.DataFrame( pd.read_csv("1wd065.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd66 = pd.DataFrame( pd.read_csv("1wd066.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd67 = pd.DataFrame( pd.read_csv("1wd067.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd68 = pd.DataFrame( pd.read_csv("1wd068.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd69 = pd.DataFrame( pd.read_csv("1wd069.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd70 = pd.DataFrame( pd.read_csv("1wd070.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd71 = pd.DataFrame( pd.read_csv("1wd071.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd72 = pd.DataFrame( pd.read_csv("1wd072.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd73 = pd.DataFrame( pd.read_csv("1wd073.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd74 = pd.DataFrame( pd.read_csv("1wd074.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd75 = pd.DataFrame( pd.read_csv("1wd075.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd76 = pd.DataFrame( pd.read_csv("1wd076.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd77 = pd.DataFrame( pd.read_csv("1wd077.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd78 = pd.DataFrame( pd.read_csv("1wd078.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd79 = pd.DataFrame( pd.read_csv("1wd079.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd80 = pd.DataFrame( pd.read_csv("1wd080.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd81 = pd.DataFrame( pd.read_csv("1wd081.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd82 = pd.DataFrame( pd.read_csv("1wd082.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd83 = pd.DataFrame( pd.read_csv("1wd083.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd84 = pd.DataFrame( pd.read_csv("1wd084.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd85 = pd.DataFrame( pd.read_csv("1wd085.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd86 = pd.DataFrame( pd.read_csv("1wd086.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd87 = pd.DataFrame( pd.read_csv("1wd087.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd88 = pd.DataFrame( pd.read_csv("1wd088.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd89 = pd.DataFrame( pd.read_csv("1wd089.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd90 = pd.DataFrame( pd.read_csv("1wd090.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd91 = pd.DataFrame( pd.read_csv("1wd091.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd92 = pd.DataFrame( pd.read_csv("1wd092.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd93 = pd.DataFrame( pd.read_csv("1wd093.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd94 = pd.DataFrame( pd.read_csv("1wd094.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd95 = pd.DataFrame( pd.read_csv("1wd095.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd96 = pd.DataFrame( pd.read_csv("1wd096.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd97 = pd.DataFrame( pd.read_csv("1wd097.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd98 = pd.DataFrame( pd.read_csv("1wd098.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd99 = pd.DataFrame( pd.read_csv("1wd099.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfd100 = pd.DataFrame( pd.read_csv("1wd100.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))

# %%
#Arreglos de los DataFrames
dfdn = [dfd1,dfd2,dfd3,dfd4,dfd5,dfd6,dfd7,dfd8,dfd9,dfd10,dfd11,dfd12,dfd13,dfd14,dfd15,dfd16,dfd17,dfd18,dfd19,dfd20,dfd21,dfd22,dfd23,dfd24,dfd25,dfd26,dfd27,dfd28,dfd29,dfd30,dfd31,dfd32,dfd33,dfd34,dfd35,dfd36,dfd37,dfd38,dfd39,dfd40,dfd41,dfd42,dfd43,dfd44,dfd45,dfd46,dfd47,dfd48,dfd49,dfd50,dfd51,dfd52,dfd53,dfd54,dfd55,dfd56,dfd57,dfd58,dfd59,dfd60,dfd61,dfd62,dfd63,dfd64,dfd65,dfd66,dfd67,dfd68,dfd69,dfd70,dfd71,dfd72,dfd73,dfd74,dfd75,dfd76,dfd77,dfd78,dfd79,dfd80,dfd81,dfd82,dfd83,dfd84,dfd85,dfd86,dfd87,dfd88,dfd89,dfd90,dfd91,dfd92,dfd93,dfd94,dfd95,dfd96,dfd97,dfd98,dfd99,dfd100]

# %%
#Se toma el último dato de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dfdn[i].X.iloc[9999]
    y = dfdn[i].Y.iloc[9999]
    datx.append(x)
    daty.append(y)
dfdLast = pd.DataFrame({"X" : datx, "Y" : daty})
dfdLast.index = np.arange(1, 101)
dfdLast
# Out:
#           X      Y
# 1    2065.0 -107.0
# 2    2069.0   43.0
# 3    1953.0   35.0
# 4    2035.0 -125.0
# 5    2099.0    1.0
# 6    2191.0   53.0
# 7    1915.0   37.0
# 8    1919.0  153.0
# 9    1979.0  163.0
# 10   2051.0   57.0
# 11   1895.0  -13.0
# 12   1907.0    9.0
# 13   2215.0  125.0
# 14   1913.0  -73.0
# 15   2075.0  119.0
# 16   2029.0  -93.0
# 17   1867.0  -75.0
# 18   1999.0  -35.0
# 19   1821.0   11.0
# 20   2023.0  -23.0
# 21   2045.0  -35.0
# 22   2079.0   47.0
# 23   2035.0  -59.0
# 24   2015.0   35.0
# 25   1923.0 -137.0
# 26   2029.0   25.0
# 27   2119.0   -9.0
# 28   1965.0   35.0
# 29   1951.0 -151.0
# 30   2065.0  -57.0
# ..      ...    ...
# 71   2061.0    5.0
# 72   1823.0 -151.0
# 73   1825.0  -33.0
# 74   2009.0    9.0
# 75   2069.0 -147.0
# 76   1873.0   19.0
# 77   1995.0  -53.0
# 78   1927.0    5.0
# 79   1893.0   55.0
# 80   1931.0  121.0
# 81   1809.0  -99.0
# 82   1999.0   45.0
# 83   1947.0  -39.0
# 84   2031.0  189.0
# 85   1993.0  191.0
# ...

# %%
#Descripción de datos.
dfdLast.describe()
# Out:
#                  X           Y
# count   100.000000  100.000000
# mean   1997.800000   17.280000
# std     101.356058   95.142645
# min    1747.000000 -151.000000
# 25%    1918.500000  -46.500000
# 50%    2009.000000   15.000000
# 75%    2065.000000   55.500000
# max    2249.000000  377.000000

# %%
#Boxplot para los últimos datos.
dfdLast.plot.box(grid=True,color='green')

# %%
#Histograma con "bins" columnas.
hist = dfdLast.hist(bins=40, color='green')

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfdLast["X"]
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.992, p=0.804
# La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfdLast["Y"]
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.961, p=0.005
# La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)

# %%
#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasX, DesvX = ss.norm.fit(dfdLast["X"])
print("Media ajustada a la normal =", MediasX)
print("Desviación ajustada a la normal =", DesvX)

#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasY, DesvY = ss.norm.fit(dfdLast["Y"])
print("Media ajustada a la normal =", MediasY)
print("Desviación ajustada a la normal =", DesvY)
# Out:
# Media ajustada a la normal = 1997.8
# Desviación ajustada a la normal = 100.84800444232896
# Media ajustada a la normal = 17.28
# Desviación ajustada a la normal = 94.66573614566148

# %% [markdown]
# Se evalúa lo mismo con el dato número 100 de cada partícula.

# %%
#Se toma eldato 100 de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dfdn[i].X.iloc[100]
    y = dfdn[i].Y.iloc[100]
    datx.append(x)
    daty.append(y)
dfdCien = pd.DataFrame({"X" : datx, "Y" : daty})
dfdCien.index = np.arange(1, 101)
dfdCien
# Out:
#         X     Y
# 1    16.0   8.0
# 2    24.0  22.0
# 3    36.0   2.0
# 4    26.0   6.0
# 5    18.0  -2.0
# 6     8.0 -14.0
# 7     8.0   8.0
# 8    34.0   8.0
# 9    20.0 -10.0
# 10   20.0  -8.0
# 11   12.0  -8.0
# 12   14.0 -16.0
# 13    4.0  -2.0
# 14   20.0   0.0
# 15   24.0   6.0
# 16   16.0   0.0
# 17   18.0   2.0
# 18   24.0  -2.0
# 19   14.0   4.0
# 20   14.0  -8.0
# 21   14.0 -12.0
# 22   14.0 -10.0
# 23   12.0 -12.0
# 24   26.0  16.0
# 25   20.0  -4.0
# 26   30.0   8.0
# 27   28.0  14.0
# 28   32.0  -2.0
# 29   22.0  -6.0
# 30   14.0   2.0
# ..    ...   ...
# 71   20.0 -14.0
# 72   12.0   4.0
# 73   14.0  -4.0
# 74   20.0  16.0
# 75   12.0   8.0
# 76    2.0   8.0
# 77   14.0  10.0
# 78    2.0  10.0
# 79   16.0  -8.0
# 80   28.0  -2.0
# 81   14.0  -6.0
# 82   26.0  14.0
# 83   24.0 -36.0
# 84   16.0  -4.0
# 85    4.0   2.0
# 86   16.0  18.0
# 87   32.0  -6.0
# 88    2.0  -2.0
# 89    6.0  -8.0
# 90   14.0  -2.0
# 91   26.0  12.0
# 92   26.0  14.0
# 93   18.0  12.0
# ...

# %%
#Descripción de datos.
dfdCien.describe()
# Out:
#                 X           Y
# count  100.000000  100.000000
# mean    19.820000    0.900000
# std      9.535028   10.511658
# min     -2.000000  -36.000000
# 25%     14.000000   -6.000000
# 50%     20.000000    0.000000
# 75%     26.000000    8.000000
# max     42.000000   26.000000

# %%
#Boxplot para los 100° datos.
dfdCien.plot.box(grid=True,color='green')

# %%
#Histograma con "bins" columnas.
hist = dfdCien.hist(bins=30, color='green')

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfdCien["X"]
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.988, p=0.517
# La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfdLast["Y"]
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.961, p=0.005
# La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)

# %%
#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasX, DesvX = ss.norm.fit(dfdCien["X"])
print("Media ajustada a la normal =", MediasX)
print("Desviación ajustada a la normal =", DesvX)

#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasY, DesvY = ss.norm.fit(dfdCien["Y"])
print("Media ajustada a la normal =", MediasY)
print("Desviación ajustada a la normal =", DesvY)
# Out:
# Media ajustada a la normal = 19.82
# Desviación ajustada a la normal = 9.487233527219619
# Media ajustada a la normal = 0.9
# Desviación ajustada a la normal = 10.458967444255672

# %%
#Graficamos la trayectoria de la partícula 1wd050
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfd50["X"], dfd50["Y"], label='x', marker=".", color='green')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1wd100
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfd100["X"], dfd100["Y"], label='x', marker=".", color='green')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1wd088
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfd88["X"], dfd88["Y"], label='x', marker=".", color='green')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1wd031
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfd31["X"], dfd31["Y"], label='x', marker=".", color='green')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de 50 partículas 
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfd50["X"], dfd50["Y"], marker=".")
plt.plot(dfd51["X"], dfd51["Y"], marker=".")
plt.plot(dfd52["X"], dfd52["Y"], marker=".")
plt.plot(dfd53["X"], dfd53["Y"], marker=".")
plt.plot(dfd54["X"], dfd54["Y"], marker=".")
plt.plot(dfd55["X"], dfd55["Y"], marker=".")
plt.plot(dfd56["X"], dfd56["Y"], marker=".")
plt.plot(dfd57["X"], dfd57["Y"], marker=".")
plt.plot(dfd58["X"], dfd58["Y"], marker=".")
plt.plot(dfd59["X"], dfd59["Y"], marker=".")
plt.plot(dfd60["X"], dfd60["Y"], marker=".")
plt.plot(dfd61["X"], dfd61["Y"], marker=".")
plt.plot(dfd62["X"], dfd62["Y"], marker=".")
plt.plot(dfd63["X"], dfd63["Y"], marker=".")
plt.plot(dfd64["X"], dfd64["Y"], marker=".")
plt.plot(dfd65["X"], dfd65["Y"], marker=".")
plt.plot(dfd66["X"], dfd66["Y"], marker=".")
plt.plot(dfd67["X"], dfd67["Y"], marker=".")
plt.plot(dfd68["X"], dfd68["Y"], marker=".")
plt.plot(dfd69["X"], dfd69["Y"], marker=".")
plt.plot(dfd70["X"], dfd70["Y"], marker=".")
plt.plot(dfd71["X"], dfd71["Y"], marker=".")
plt.plot(dfd72["X"], dfd72["Y"], marker=".")
plt.plot(dfd73["X"], dfd73["Y"], marker=".")
plt.plot(dfd74["X"], dfd74["Y"], marker=".")
plt.plot(dfd75["X"], dfd75["Y"], marker=".")
plt.plot(dfd76["X"], dfd76["Y"], marker=".")
plt.plot(dfd77["X"], dfd77["Y"], marker=".")
plt.plot(dfd78["X"], dfd78["Y"], marker=".")
plt.plot(dfd79["X"], dfd79["Y"], marker=".")
plt.plot(dfd80["X"], dfd80["Y"], marker=".")
plt.plot(dfd81["X"], dfd81["Y"], marker=".")
plt.plot(dfd82["X"], dfd82["Y"], marker=".")
plt.plot(dfd83["X"], dfd83["Y"], marker=".")
plt.plot(dfd84["X"], dfd84["Y"], marker=".")
plt.plot(dfd85["X"], dfd85["Y"], marker=".")
plt.plot(dfd86["X"], dfd86["Y"], marker=".")
plt.plot(dfd87["X"], dfd87["Y"], marker=".")
plt.plot(dfd88["X"], dfd88["Y"], marker=".")
plt.plot(dfd89["X"], dfd89["Y"], marker=".")
plt.plot(dfd90["X"], dfd90["Y"], marker=".")
plt.plot(dfd91["X"], dfd91["Y"], marker=".")
plt.plot(dfd92["X"], dfd92["Y"], marker=".")
plt.plot(dfd93["X"], dfd93["Y"], marker=".")
plt.plot(dfd94["X"], dfd94["Y"], marker=".")
plt.plot(dfd95["X"], dfd95["Y"], marker=".")
plt.plot(dfd96["X"], dfd96["Y"], marker=".")
plt.plot(dfd97["X"], dfd97["Y"], marker=".")
plt.plot(dfd98["X"], dfd98["Y"], marker=".")
plt.plot(dfd99["X"], dfd99["Y"], marker=".")
plt.plot(dfd100["X"], dfd100["Y"], marker=".")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **PROBABILIDAD PASO A LA DERECHA EN X y Y DE 0.60**

# %%
#Se leen los archivos de datos.
dfc1 = pd.DataFrame(pd.read_csv('1wc001.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc2 = pd.DataFrame(pd.read_csv('1wc002.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc3 = pd.DataFrame(pd.read_csv('1wc003.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc4 = pd.DataFrame(pd.read_csv('1wc004.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc5 = pd.DataFrame(pd.read_csv('1wc005.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc6 = pd.DataFrame(pd.read_csv('1wc006.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc7 = pd.DataFrame(pd.read_csv('1wc007.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc8 = pd.DataFrame(pd.read_csv('1wc008.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc9 = pd.DataFrame(pd.read_csv('1wc009.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc10 = pd.DataFrame(pd.read_csv('1wc010.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc11 = pd.DataFrame(pd.read_csv('1wc011.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc12 = pd.DataFrame(pd.read_csv('1wc012.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc13 = pd.DataFrame(pd.read_csv('1wc013.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc14 = pd.DataFrame(pd.read_csv('1wc014.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc15 = pd.DataFrame(pd.read_csv('1wc015.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc16 = pd.DataFrame(pd.read_csv('1wc016.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc17 = pd.DataFrame(pd.read_csv('1wc017.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc18 = pd.DataFrame(pd.read_csv('1wc018.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc19 = pd.DataFrame(pd.read_csv('1wc019.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc20 = pd.DataFrame(pd.read_csv('1wc020.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc21 = pd.DataFrame(pd.read_csv('1wc021.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc22 = pd.DataFrame(pd.read_csv('1wc022.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc23 = pd.DataFrame(pd.read_csv('1wc023.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc24 = pd.DataFrame(pd.read_csv('1wc024.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc25 = pd.DataFrame(pd.read_csv('1wc025.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc26 = pd.DataFrame(pd.read_csv('1wc026.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc27 = pd.DataFrame(pd.read_csv('1wc027.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc28 = pd.DataFrame(pd.read_csv('1wc028.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc29 = pd.DataFrame(pd.read_csv('1wc029.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc30 = pd.DataFrame(pd.read_csv('1wc030.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc31 = pd.DataFrame(pd.read_csv('1wc031.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc32 = pd.DataFrame(pd.read_csv('1wc032.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc33 = pd.DataFrame(pd.read_csv('1wc033.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc34 = pd.DataFrame(pd.read_csv('1wc034.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc35 = pd.DataFrame(pd.read_csv('1wc035.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc36 = pd.DataFrame(pd.read_csv('1wc036.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc37 = pd.DataFrame(pd.read_csv('1wc037.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc38 = pd.DataFrame(pd.read_csv('1wc038.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc39 = pd.DataFrame(pd.read_csv('1wc039.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc40 = pd.DataFrame(pd.read_csv('1wc040.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc41 = pd.DataFrame(pd.read_csv('1wc041.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc42 = pd.DataFrame(pd.read_csv('1wc042.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc43 = pd.DataFrame(pd.read_csv('1wc043.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc44 = pd.DataFrame(pd.read_csv('1wc044.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc45 = pd.DataFrame(pd.read_csv('1wc045.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc46 = pd.DataFrame(pd.read_csv('1wc046.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc47 = pd.DataFrame(pd.read_csv('1wc047.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc48 = pd.DataFrame(pd.read_csv('1wc048.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc49 = pd.DataFrame(pd.read_csv('1wc049.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc50 = pd.DataFrame(pd.read_csv('1wc050.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc51 = pd.DataFrame( pd.read_csv("1wc051.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc52 = pd.DataFrame( pd.read_csv("1wc052.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc53 = pd.DataFrame( pd.read_csv("1wc053.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc54 = pd.DataFrame( pd.read_csv("1wc054.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc55 = pd.DataFrame( pd.read_csv("1wc055.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc56 = pd.DataFrame( pd.read_csv("1wc056.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc57 = pd.DataFrame( pd.read_csv("1wc057.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc58 = pd.DataFrame( pd.read_csv("1wc058.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc59 = pd.DataFrame( pd.read_csv("1wc059.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc60 = pd.DataFrame( pd.read_csv("1wc060.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc61 = pd.DataFrame( pd.read_csv("1wc061.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc62 = pd.DataFrame( pd.read_csv("1wc062.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc63 = pd.DataFrame( pd.read_csv("1wc063.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc64 = pd.DataFrame( pd.read_csv("1wc064.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc65 = pd.DataFrame( pd.read_csv("1wc065.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc66 = pd.DataFrame( pd.read_csv("1wc066.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc67 = pd.DataFrame( pd.read_csv("1wc067.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc68 = pd.DataFrame( pd.read_csv("1wc068.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc69 = pd.DataFrame( pd.read_csv("1wc069.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc70 = pd.DataFrame( pd.read_csv("1wc070.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc71 = pd.DataFrame( pd.read_csv("1wc071.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc72 = pd.DataFrame( pd.read_csv("1wc072.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc73 = pd.DataFrame( pd.read_csv("1wc073.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc74 = pd.DataFrame( pd.read_csv("1wc074.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc75 = pd.DataFrame( pd.read_csv("1wc075.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc76 = pd.DataFrame( pd.read_csv("1wc076.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc77 = pd.DataFrame( pd.read_csv("1wc077.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc78 = pd.DataFrame( pd.read_csv("1wc078.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc79 = pd.DataFrame( pd.read_csv("1wc079.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc80 = pd.DataFrame( pd.read_csv("1wc080.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc81 = pd.DataFrame( pd.read_csv("1wc081.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc82 = pd.DataFrame( pd.read_csv("1wc082.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc83 = pd.DataFrame( pd.read_csv("1wc083.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc84 = pd.DataFrame( pd.read_csv("1wc084.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc85 = pd.DataFrame( pd.read_csv("1wc085.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc86 = pd.DataFrame( pd.read_csv("1wc086.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc87 = pd.DataFrame( pd.read_csv("1wc087.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc88 = pd.DataFrame( pd.read_csv("1wc088.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc89 = pd.DataFrame( pd.read_csv("1wc089.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc90 = pd.DataFrame( pd.read_csv("1wc090.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc91 = pd.DataFrame( pd.read_csv("1wc091.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc92 = pd.DataFrame( pd.read_csv("1wc092.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc93 = pd.DataFrame( pd.read_csv("1wc093.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc94 = pd.DataFrame( pd.read_csv("1wc094.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc95 = pd.DataFrame( pd.read_csv("1wc095.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc96 = pd.DataFrame( pd.read_csv("1wc096.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc97 = pd.DataFrame( pd.read_csv("1wc097.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc98 = pd.DataFrame( pd.read_csv("1wc098.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc99 = pd.DataFrame( pd.read_csv("1wc099.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfc100 = pd.DataFrame( pd.read_csv("1wc100.dat",skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))

# %%
#Arreglos de los DataFrames.
dfcn = [dfc1,dfc2,dfc3,dfc4,dfc5,dfc6,dfc7,dfc8,dfc9,dfc10,dfc11,dfc12,dfc13,dfc14,dfc15,dfc16,dfc17,dfc18,dfc19,dfc20,dfc21,dfc22,dfc23,dfc24,dfc25,dfc26,dfc27,dfc28,dfc29,dfc30,dfc31,dfc32,dfc33,dfc34,dfc35,dfc36,dfc37,dfc38,dfc39,dfc40,dfc41,dfc42,dfc43,dfc44,dfc45,dfc46,dfc47,dfc48,dfc49,dfc50,dfc51,dfc52,dfc53,dfc54,dfc55,dfc56,dfc57,dfc58,dfc59,dfc60,dfc61,dfc62,dfc63,dfc64,dfc65,dfc66,dfc67,dfc68,dfc69,dfc70,dfc71,dfc72,dfc73,dfc74,dfc75,dfc76,dfc77,dfc78,dfc79,dfc80,dfc81,dfc82,dfc83,dfc84,dfc85,dfc86,dfc87,dfc88,dfc89,dfc90,dfc91,dfc92,dfc93,dfc94,dfc95,dfc96,dfc97,dfc98,dfc99,dfc100]

# %%
#Se toma el último dato de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dfcn[i].X.iloc[9999]
    y = dfcn[i].Y.iloc[9999]
    datx.append(x)
    daty.append(y)
dfcLast = pd.DataFrame({"X" : datx, "Y" : daty})
dfcLast.index = np.arange(1, 101)
dfcLast
# Out:
#           X       Y
# 1    1995.0  1855.0
# 2    1927.0  1927.0
# 3    1967.0  2031.0
# 4    1867.0  1869.0
# 5    1911.0  2093.0
# 6    1917.0  2097.0
# 7    1989.0  2019.0
# 8    2053.0  2049.0
# 9    1769.0  2083.0
# 10   1953.0  1999.0
# 11   1903.0  2011.0
# 12   2061.0  2061.0
# 13   1859.0  2023.0
# 14   2143.0  1989.0
# 15   1957.0  1947.0
# 16   1999.0  1931.0
# 17   2075.0  1883.0
# 18   2131.0  2027.0
# 19   2029.0  1753.0
# 20   1805.0  1911.0
# 21   1871.0  1973.0
# 22   1947.0  2099.0
# 23   1915.0  2051.0
# 24   2021.0  1971.0
# 25   2059.0  1911.0
# 26   1895.0  2009.0
# 27   2023.0  2013.0
# 28   1983.0  2043.0
# 29   2015.0  2023.0
# 30   1913.0  2031.0
# ..      ...     ...
# 71   1937.0  2073.0
# 72   1991.0  1869.0
# 73   2013.0  2029.0
# 74   2071.0  1947.0
# 75   2097.0  1995.0
# 76   2003.0  2081.0
# 77   1933.0  1835.0
# 78   2035.0  1845.0
# 79   1955.0  1983.0
# 80   1931.0  1877.0
# 81   1963.0  1829.0
# 82   2001.0  1911.0
# 83   2175.0  1893.0
# ...

# %%
#Descripción de datos.
dfcLast.describe()
# Out:
#                  X            Y
# count   100.000000   100.000000
# mean   1989.080000  1988.420000
# std      96.513743   108.241516
# min    1769.000000  1641.000000
# 25%    1923.000000  1924.500000
# 50%    1990.000000  1989.000000
# 75%    2051.500000  2059.000000
# max    2269.000000  2263.000000

# %%
#Boxplot para los últimos datos.
dfcLast.plot.box(grid=True,color='y')

# %%
#Histograma con "bins" columnas.
hist = dfcLast.hist(bins=40, color='y')

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfcLast
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.992, p=0.347
# La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)

# %%
#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasX, DesvX = ss.norm.fit(dfcLast["X"])
print("Media ajustada a la normal =", MediasX)
print("Desviación ajustada a la normal =", DesvX)

#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasY, DesvY = ss.norm.fit(dfcLast["Y"])
print("Media ajustada a la normal =", MediasY)
print("Desviación ajustada a la normal =", DesvY)
# Out:
# Media ajustada a la normal = 1989.08
# Desviación ajustada a la normal = 96.02996199103693
# Media ajustada a la normal = 1988.42
# Desviación ajustada a la normal = 107.69894892709027

# %% [markdown]
# Se evalúa lo mismo con el paso número 100 de cada partícula.

# %%
#Se toma eldato 100 de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dfcn[i].X.iloc[100]
    y = dfcn[i].Y.iloc[100]
    datx.append(x)
    daty.append(y)
dfcCien = pd.DataFrame({"X" : datx, "Y" : daty})
dfcCien.index = np.arange(1, 101)
dfcCien
# Out:
#         X     Y
# 1    16.0  30.0
# 2    22.0  20.0
# 3    12.0  14.0
# 4    34.0  20.0
# 5    14.0  26.0
# 6    16.0  14.0
# 7    30.0  28.0
# 8    28.0  34.0
# 9    20.0   8.0
# 10   20.0  20.0
# 11   30.0  22.0
# 12   28.0  22.0
# 13   14.0  22.0
# 14    6.0  10.0
# 15   38.0  20.0
# 16   26.0   4.0
# 17   16.0  18.0
# 18   28.0  26.0
# 19   30.0  14.0
# 20   10.0  24.0
# 21   12.0  10.0
# 22   26.0  26.0
# 23   32.0  22.0
# 24   20.0  28.0
# 25   30.0   6.0
# 26    8.0  38.0
# 27   28.0  22.0
# 28   42.0  26.0
# 29   14.0  22.0
# 30   34.0  36.0
# ..    ...   ...
# 71   10.0  30.0
# 72   34.0  32.0
# 73   26.0  26.0
# 74    4.0  26.0
# 75   10.0  14.0
# 76   22.0  24.0
# 77   16.0  12.0
# 78   14.0  26.0
# 79   12.0   4.0
# 80    6.0  20.0
# 81   28.0   2.0
# 82   22.0  20.0
# 83    8.0   4.0
# 84   28.0  20.0
# 85   16.0  10.0
# 86   20.0  26.0
# 87   22.0  30.0
# 88   28.0  20.0
# 89   18.0  28.0
# 90   28.0  16.0
# 91   16.0  28.0
# 92   10.0  30.0
# 93   36.0   4.0
# ...

# %%
#Descripción de datos.
dfcCien.describe()
# Out:
#                 X           Y
# count  100.000000  100.000000
# mean    21.280000   21.060000
# std     10.392383    9.549256
# min      2.000000  -10.000000
# 25%     13.500000   15.500000
# 50%     20.000000   22.000000
# 75%     28.000000   28.000000
# max     46.000000   42.000000

# %%
#Boxplot para los 100° datos.
dfcCien.plot.box(grid=True,color='y')

# %%
#Histograma con "bins" columnas.
hist = dfcCien.hist(bins=30, color='y')

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfcCien
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.992, p=0.348
# La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)

# %%
#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasX, DesvX = ss.norm.fit(dfcCien["X"])
print("Media ajustada a la normal =", MediasX)
print("Desviación ajustada a la normal =", DesvX)

#Se hace un ajuste para aproximar a una Normal para las "Y".
MediasY, DesvY = ss.norm.fit(dfcCien["Y"])
print("Media ajustada a la normal =", MediasY)
print("Desviación ajustada a la normal =", DesvY)
# Out:
# Media ajustada a la normal = 21.28
# Desviación ajustada a la normal = 10.340290131326102
# Media ajustada a la normal = 21.06
# Desviación ajustada a la normal = 9.501389372086589

# %%
#Graficamos la trayectoria de la partícula 1wc001
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfc1["X"], dfc1["Y"], label='x', marker=".", color='y')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1wc027
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfc27["X"], dfc27["Y"], label='x', marker=".", color='y')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1wc015
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfc15["X"], dfc15["Y"], label='x', marker=".", color='y')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de la partícula 1wc094
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfc94["X"], dfc94["Y"], label='x', marker=".", color='y')
plt.grid(True)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %%
#Graficamos la trayectoria de 50 partículas 
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfc50["X"], dfc50["Y"], marker=".")
plt.plot(dfc51["X"], dfc51["Y"], marker=".")
plt.plot(dfc52["X"], dfc52["Y"], marker=".")
plt.plot(dfc53["X"], dfc53["Y"], marker=".")
plt.plot(dfc54["X"], dfc54["Y"], marker=".")
plt.plot(dfc55["X"], dfc55["Y"], marker=".")
plt.plot(dfc56["X"], dfc56["Y"], marker=".")
plt.plot(dfc57["X"], dfc57["Y"], marker=".")
plt.plot(dfc58["X"], dfc58["Y"], marker=".")
plt.plot(dfc59["X"], dfc59["Y"], marker=".")
plt.plot(dfc60["X"], dfc60["Y"], marker=".")
plt.plot(dfc61["X"], dfc61["Y"], marker=".")
plt.plot(dfc62["X"], dfc62["Y"], marker=".")
plt.plot(dfc63["X"], dfc63["Y"], marker=".")
plt.plot(dfc64["X"], dfc64["Y"], marker=".")
plt.plot(dfc65["X"], dfc65["Y"], marker=".")
plt.plot(dfc66["X"], dfc66["Y"], marker=".")
plt.plot(dfc67["X"], dfc67["Y"], marker=".")
plt.plot(dfc68["X"], dfc68["Y"], marker=".")
plt.plot(dfc69["X"], dfc69["Y"], marker=".")
plt.plot(dfc70["X"], dfc70["Y"], marker=".")
plt.plot(dfc71["X"], dfc71["Y"], marker=".")
plt.plot(dfc72["X"], dfc72["Y"], marker=".")
plt.plot(dfc73["X"], dfc73["Y"], marker=".")
plt.plot(dfc74["X"], dfc74["Y"], marker=".")
plt.plot(dfc75["X"], dfc75["Y"], marker=".")
plt.plot(dfc76["X"], dfc76["Y"], marker=".")
plt.plot(dfc77["X"], dfc77["Y"], marker=".")
plt.plot(dfc78["X"], dfc78["Y"], marker=".")
plt.plot(dfc79["X"], dfc79["Y"], marker=".")
plt.plot(dfc80["X"], dfc80["Y"], marker=".")
plt.plot(dfc81["X"], dfc81["Y"], marker=".")
plt.plot(dfc82["X"], dfc82["Y"], marker=".")
plt.plot(dfc83["X"], dfc83["Y"], marker=".")
plt.plot(dfc84["X"], dfc84["Y"], marker=".")
plt.plot(dfc85["X"], dfc85["Y"], marker=".")
plt.plot(dfc86["X"], dfc86["Y"], marker=".")
plt.plot(dfc87["X"], dfc87["Y"], marker=".")
plt.plot(dfc88["X"], dfc88["Y"], marker=".")
plt.plot(dfc89["X"], dfc89["Y"], marker=".")
plt.plot(dfc90["X"], dfc90["Y"], marker=".")
plt.plot(dfc91["X"], dfc91["Y"], marker=".")
plt.plot(dfc92["X"], dfc92["Y"], marker=".")
plt.plot(dfc93["X"], dfc93["Y"], marker=".")
plt.plot(dfc94["X"], dfc94["Y"], marker=".")
plt.plot(dfc95["X"], dfc95["Y"], marker=".")
plt.plot(dfc96["X"], dfc96["Y"], marker=".")
plt.plot(dfc97["X"], dfc97["Y"], marker=".")
plt.plot(dfc98["X"], dfc98["Y"], marker=".")
plt.plot(dfc99["X"], dfc99["Y"], marker=".")
plt.plot(dfc100["X"], dfc100["Y"], marker=".")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Caminata alateoria")
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **LENARD JONES 1**

# %% [markdown]
#  Número de Átomos                400
#
#  Número de Ciclos              15100
#
#  Frecuencia de Escritura          100
#
#  Frecuencia de Resguardo            1
#
#  Frecuencia de Despl.              10
#
#  Radio de Corte del Pot.      15.8114
#
#  Densidad Reducida             0.4000
#
#  Frac. en Vol.                 0.3142
#
#  Temperatura                   1.5000

# %%
#Leemos cada archivo de datos con el potencial de Lenard Jones (1) y 
#los almacenamos, cada uno, en un DataFrame. 
#Se usa Skiprows de -1 para dejar pasar un espacio y nombrar a las columnas "x" y "y".
dfl1 = pd.DataFrame(pd.read_csv('1lj001.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl2 = pd.DataFrame(pd.read_csv('1lj002.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl3 = pd.DataFrame(pd.read_csv('1lj003.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl4 = pd.DataFrame(pd.read_csv('1lj004.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl5 = pd.DataFrame(pd.read_csv('1lj005.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl6 = pd.DataFrame(pd.read_csv('1lj006.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl7 = pd.DataFrame(pd.read_csv('1lj007.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl8 = pd.DataFrame(pd.read_csv('1lj008.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl9 = pd.DataFrame(pd.read_csv('1lj009.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl10 = pd.DataFrame(pd.read_csv('1lj010.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl11 = pd.DataFrame(pd.read_csv('1lj011.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl12 = pd.DataFrame(pd.read_csv('1lj012.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl13 = pd.DataFrame(pd.read_csv('1lj013.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl14 = pd.DataFrame(pd.read_csv('1lj014.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl15 = pd.DataFrame(pd.read_csv('1lj015.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl16 = pd.DataFrame(pd.read_csv('1lj016.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl17 = pd.DataFrame(pd.read_csv('1lj017.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl18 = pd.DataFrame(pd.read_csv('1lj018.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl19 = pd.DataFrame(pd.read_csv('1lj019.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl20 = pd.DataFrame(pd.read_csv('1lj020.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl21 = pd.DataFrame(pd.read_csv('1lj021.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl22 = pd.DataFrame(pd.read_csv('1lj022.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl23 = pd.DataFrame(pd.read_csv('1lj023.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl24 = pd.DataFrame(pd.read_csv('1lj024.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl25 = pd.DataFrame(pd.read_csv('1lj025.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl26 = pd.DataFrame(pd.read_csv('1lj026.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl27 = pd.DataFrame(pd.read_csv('1lj027.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl28 = pd.DataFrame(pd.read_csv('1lj028.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl29 = pd.DataFrame(pd.read_csv('1lj029.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl30 = pd.DataFrame(pd.read_csv('1lj030.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl31 = pd.DataFrame(pd.read_csv('1lj031.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl32 = pd.DataFrame(pd.read_csv('1lj032.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl33 = pd.DataFrame(pd.read_csv('1lj033.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl34 = pd.DataFrame(pd.read_csv('1lj034.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl35 = pd.DataFrame(pd.read_csv('1lj035.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl36 = pd.DataFrame(pd.read_csv('1lj036.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl37 = pd.DataFrame(pd.read_csv('1lj037.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl38 = pd.DataFrame(pd.read_csv('1lj038.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl39 = pd.DataFrame(pd.read_csv('1lj039.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl40 = pd.DataFrame(pd.read_csv('1lj040.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl41 = pd.DataFrame(pd.read_csv('1lj041.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl42 = pd.DataFrame(pd.read_csv('1lj042.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl43 = pd.DataFrame(pd.read_csv('1lj043.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl44 = pd.DataFrame(pd.read_csv('1lj044.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl45 = pd.DataFrame(pd.read_csv('1lj045.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl46 = pd.DataFrame(pd.read_csv('1lj046.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl47 = pd.DataFrame(pd.read_csv('1lj047.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl48 = pd.DataFrame(pd.read_csv('1lj048.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl49 = pd.DataFrame(pd.read_csv('1lj049.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl50 = pd.DataFrame(pd.read_csv('1lj050.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl51 = pd.DataFrame(pd.read_csv("1lj051.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl52 = pd.DataFrame(pd.read_csv("1lj052.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl53 = pd.DataFrame(pd.read_csv("1lj053.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl54 = pd.DataFrame(pd.read_csv("1lj054.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl55 = pd.DataFrame(pd.read_csv("1lj055.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl56 = pd.DataFrame(pd.read_csv("1lj056.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl57 = pd.DataFrame(pd.read_csv("1lj057.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl58 = pd.DataFrame(pd.read_csv("1lj058.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl59 = pd.DataFrame(pd.read_csv("1lj059.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl60 = pd.DataFrame(pd.read_csv("1lj060.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl61 = pd.DataFrame(pd.read_csv("1lj061.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl62 = pd.DataFrame(pd.read_csv("1lj062.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl63 = pd.DataFrame(pd.read_csv("1lj063.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl64 = pd.DataFrame(pd.read_csv("1lj064.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl65 = pd.DataFrame(pd.read_csv("1lj065.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl66 = pd.DataFrame(pd.read_csv("1lj066.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl67 = pd.DataFrame(pd.read_csv("1lj067.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl68 = pd.DataFrame(pd.read_csv("1lj068.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl69 = pd.DataFrame(pd.read_csv("1lj069.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl70 = pd.DataFrame(pd.read_csv("1lj070.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl71 = pd.DataFrame(pd.read_csv("1lj071.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl72 = pd.DataFrame(pd.read_csv("1lj072.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl73 = pd.DataFrame(pd.read_csv("1lj073.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl74 = pd.DataFrame(pd.read_csv("1lj074.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl75 = pd.DataFrame(pd.read_csv("1lj075.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl76 = pd.DataFrame(pd.read_csv("1lj076.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl77 = pd.DataFrame(pd.read_csv("1lj077.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl78 = pd.DataFrame(pd.read_csv("1lj078.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl79 = pd.DataFrame(pd.read_csv("1lj079.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl80 = pd.DataFrame(pd.read_csv("1lj080.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl81 = pd.DataFrame(pd.read_csv("1lj081.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl82 = pd.DataFrame(pd.read_csv("1lj082.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl83 = pd.DataFrame(pd.read_csv("1lj083.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl84 = pd.DataFrame(pd.read_csv("1lj084.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl85 = pd.DataFrame(pd.read_csv("1lj085.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl86 = pd.DataFrame(pd.read_csv("1lj086.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl87 = pd.DataFrame(pd.read_csv("1lj087.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl88 = pd.DataFrame(pd.read_csv("1lj088.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl89 = pd.DataFrame(pd.read_csv("1lj089.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl90 = pd.DataFrame(pd.read_csv("1lj090.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl91 = pd.DataFrame(pd.read_csv("1lj091.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl92 = pd.DataFrame(pd.read_csv("1lj092.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl93 = pd.DataFrame(pd.read_csv("1lj093.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl94 = pd.DataFrame(pd.read_csv("1lj094.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl95 = pd.DataFrame(pd.read_csv("1lj095.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl96 = pd.DataFrame(pd.read_csv("1lj096.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl97 = pd.DataFrame(pd.read_csv("1lj097.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl98 = pd.DataFrame(pd.read_csv("1lj098.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl99 = pd.DataFrame(pd.read_csv("1lj099.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfl100 = pd.DataFrame(pd.read_csv("1lj100.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))

# %%
#Arreglo de los DataFrames.
dfln = [dfl1,dfl2,dfl3,dfl4,dfl5,dfl6,dfl7,dfl8,dfl9,dfl10,dfl11,dfl12,dfl13,dfl14,dfl15,dfl16,dfl17,dfl18,dfl19,dfl20,dfl21,dfl22,dfl23,dfl24,dfl25,dfl26,dfl27,dfl28,dfl29,dfl30,dfl31,dfl32,dfl33,dfl34,dfl35,dfl36,dfl37,dfl38,dfl39,dfl40,dfl41,dfl42,dfl43,dfl44,dfl45,dfl46,dfl47,dfl48,dfl49,dfl50,dfl51,dfl52,dfl53,dfl54,dfl55,dfl56,dfl57,dfl58,dfl59,dfl60,dfl61,dfl62,dfl63,dfl64,dfl65,dfl66,dfl67,dfl68,dfl69,dfl70,dfl71,dfl72,dfl73,dfl74,dfl75,dfl76,dfl77,dfl78,dfl79,dfl80,dfl81,dfl82,dfl83,dfl84,dfl85,dfl86,dfl87,dfl88,dfl89,dfl90,dfl91,dfl92,dfl93,dfl94,dfl95,dfl96,dfl97,dfl98,dfl99,dfl100]

# %%
#Se toma el último dato de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dfln[i].X.iloc[99]
    y = dfln[i].Y.iloc[99]
    datx.append(x)
    daty.append(y)
dflLast = pd.DataFrame({"X" : datx, "Y" : daty})
dflLast.index = np.arange(1, 101)
#dflLast

# %%
#Descripci+on de los datos.
dflLast.describe()
# Out:
#                 X           Y
# count  100.000000  100.000000
# mean    -0.283969    9.555201
# std      8.949158    2.308449
# min    -15.524773    4.530246
# 25%     -7.586798    7.754355
# 50%     -0.295136    9.715925
# 75%      6.810190   11.412944
# max     15.759846   13.529779

# %%
#Boxplot para los últimos datos.
dflLast.plot.box(grid=True,color='orange')

# %%
#Histograma con "bins" columnas.
hist = dflLast.hist(bins=40, color='orange')

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dflLast
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.866, p=0.000
# La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)

# %%
plt.figure(figsize=(10, 10))
plt.plot(dfl21["X"], dfl21["Y"], marker=".", color="orange")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (1)")
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.plot(dfl20["X"], dfl20["Y"], marker=".", color="orange")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (1)")
plt.show()

# %%
#Graficamos el movimiento de las 100 partículas bajo el potencial de Lenard Jones (1).
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfl1["X"], dfl1["Y"], marker=".")
plt.plot(dfl2["X"], dfl2["Y"], marker=".")
plt.plot(dfl3["X"], dfl3["Y"], marker=".")
plt.plot(dfl4["X"], dfl4["Y"], marker=".")
plt.plot(dfl5["X"], dfl5["Y"], marker=".")
plt.plot(dfl6["X"], dfl6["Y"], marker=".")
plt.plot(dfl7["X"], dfl7["Y"], marker=".")
plt.plot(dfl8["X"], dfl8["Y"], marker=".")
plt.plot(dfl9["X"], dfl9["Y"], marker=".")
plt.plot(dfl10["X"], dfl10["Y"], marker=".")
plt.plot(dfl11["X"], dfl11["Y"], marker=".")
plt.plot(dfl12["X"], dfl12["Y"], marker=".")
plt.plot(dfl13["X"], dfl13["Y"], marker=".")
plt.plot(dfl14["X"], dfl14["Y"], marker=".")
plt.plot(dfl15["X"], dfl15["Y"], marker=".")
plt.plot(dfl16["X"], dfl16["Y"], marker=".")
plt.plot(dfl17["X"], dfl17["Y"], marker=".")
plt.plot(dfl18["X"], dfl18["Y"], marker=".")
plt.plot(dfl19["X"], dfl19["Y"], marker=".")
#plt.plot(dfl20["X"], dfl20["Y"], marker=".")
plt.plot(dfl21["X"], dfl21["Y"], marker=".")
plt.plot(dfl22["X"], dfl22["Y"], marker=".")
plt.plot(dfl23["X"], dfl23["Y"], marker=".")
plt.plot(dfl24["X"], dfl24["Y"], marker=".")
plt.plot(dfl25["X"], dfl25["Y"], marker=".")
plt.plot(dfl26["X"], dfl26["Y"], marker=".")
plt.plot(dfl27["X"], dfl27["Y"], marker=".")
plt.plot(dfl28["X"], dfl28["Y"], marker=".")
plt.plot(dfl29["X"], dfl29["Y"], marker=".")
plt.plot(dfl30["X"], dfl30["Y"], marker=".")
plt.plot(dfl31["X"], dfl31["Y"], marker=".")
plt.plot(dfl32["X"], dfl32["Y"], marker=".")
plt.plot(dfl33["X"], dfl33["Y"], marker=".")
plt.plot(dfl34["X"], dfl34["Y"], marker=".")
plt.plot(dfl35["X"], dfl35["Y"], marker=".")
plt.plot(dfl36["X"], dfl36["Y"], marker=".")
plt.plot(dfl37["X"], dfl37["Y"], marker=".")
plt.plot(dfl38["X"], dfl38["Y"], marker=".")
plt.plot(dfl39["X"], dfl39["Y"], marker=".")
plt.plot(dfl40["X"], dfl40["Y"], marker=".")
plt.plot(dfl41["X"], dfl41["Y"], marker=".")
plt.plot(dfl42["X"], dfl42["Y"], marker=".")
plt.plot(dfl43["X"], dfl43["Y"], marker=".")
plt.plot(dfl44["X"], dfl44["Y"], marker=".")
plt.plot(dfl45["X"], dfl45["Y"], marker=".")
plt.plot(dfl46["X"], dfl46["Y"], marker=".")
plt.plot(dfl47["X"], dfl47["Y"], marker=".")
plt.plot(dfl48["X"], dfl48["Y"], marker=".")
plt.plot(dfl49["X"], dfl49["Y"], marker=".")
plt.plot(dfl50["X"], dfl50["Y"], marker=".")
plt.plot(dfl51["X"], dfl51["Y"], marker=".")
plt.plot(dfl52["X"], dfl52["Y"], marker=".")
plt.plot(dfl53["X"], dfl53["Y"], marker=".")
plt.plot(dfl54["X"], dfl54["Y"], marker=".")
plt.plot(dfl55["X"], dfl55["Y"], marker=".")
plt.plot(dfl56["X"], dfl56["Y"], marker=".")
plt.plot(dfl57["X"], dfl57["Y"], marker=".")
plt.plot(dfl58["X"], dfl58["Y"], marker=".")
plt.plot(dfl59["X"], dfl59["Y"], marker=".")
plt.plot(dfl60["X"], dfl60["Y"], marker=".")
plt.plot(dfl61["X"], dfl61["Y"], marker=".")
plt.plot(dfl62["X"], dfl62["Y"], marker=".")
plt.plot(dfl63["X"], dfl63["Y"], marker=".")
plt.plot(dfl64["X"], dfl64["Y"], marker=".")
plt.plot(dfl65["X"], dfl65["Y"], marker=".")
plt.plot(dfl66["X"], dfl66["Y"], marker=".")
plt.plot(dfl67["X"], dfl67["Y"], marker=".")
plt.plot(dfl68["X"], dfl68["Y"], marker=".")
plt.plot(dfl69["X"], dfl69["Y"], marker=".")
plt.plot(dfl70["X"], dfl70["Y"], marker=".")
plt.plot(dfl71["X"], dfl71["Y"], marker=".")
plt.plot(dfl72["X"], dfl72["Y"], marker=".")
plt.plot(dfl73["X"], dfl73["Y"], marker=".")
plt.plot(dfl74["X"], dfl74["Y"], marker=".")
plt.plot(dfl75["X"], dfl75["Y"], marker=".")
plt.plot(dfl76["X"], dfl76["Y"], marker=".")
plt.plot(dfl77["X"], dfl77["Y"], marker=".")
plt.plot(dfl78["X"], dfl78["Y"], marker=".")
plt.plot(dfl79["X"], dfl79["Y"], marker=".")
plt.plot(dfl80["X"], dfl80["Y"], marker=".")
plt.plot(dfl81["X"], dfl81["Y"], marker=".")
plt.plot(dfl82["X"], dfl82["Y"], marker=".")
plt.plot(dfl83["X"], dfl83["Y"], marker=".")
plt.plot(dfl84["X"], dfl84["Y"], marker=".")
plt.plot(dfl85["X"], dfl85["Y"], marker=".")
plt.plot(dfl86["X"], dfl86["Y"], marker=".")
plt.plot(dfl87["X"], dfl87["Y"], marker=".")
plt.plot(dfl88["X"], dfl88["Y"], marker=".")
plt.plot(dfl89["X"], dfl89["Y"], marker=".")
plt.plot(dfl90["X"], dfl90["Y"], marker=".")
plt.plot(dfl91["X"], dfl91["Y"], marker=".")
plt.plot(dfl92["X"], dfl92["Y"], marker=".")
plt.plot(dfl93["X"], dfl93["Y"], marker=".")
plt.plot(dfl94["X"], dfl94["Y"], marker=".")
plt.plot(dfl95["X"], dfl95["Y"], marker=".")
plt.plot(dfl96["X"], dfl96["Y"], marker=".")
plt.plot(dfl97["X"], dfl97["Y"], marker=".")
plt.plot(dfl98["X"], dfl98["Y"], marker=".")
plt.plot(dfl99["X"], dfl99["Y"], marker=".")
plt.plot(dfl100["X"], dfl100["Y"], marker=".")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (1)")
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **LENARD JONES 2**

# %% [markdown]
#  Número de Átomos                 400
#
#  Número de Ciclos               15100
#
#  Frecuencia de Escritura          100
#
#  Frecuencia de Resguardo            1
#
#  Frecuencia de Despl.              10
#
#  Radio de Corte del Pot.      15.8114
#
#  Densidad Reducida             0.4000
#
#  Frac. en Vol.                 0.3142
#
#  Temperatura                   0.7500

# %%
#Leemos cada archivo de datos con el potencial de Lenard Jones (2) y 
#los almacenamos, cada uno, en un DataFrame. 
#Se usa Skiprows de -1 para dejar pasar un espacio y nombrar a las columnas "x" y "y".
dfll1 = pd.DataFrame(pd.read_csv('2lj001.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll2 = pd.DataFrame(pd.read_csv('2lj002.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll3 = pd.DataFrame(pd.read_csv('2lj003.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll4 = pd.DataFrame(pd.read_csv('2lj004.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll5 = pd.DataFrame(pd.read_csv('2lj005.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll6 = pd.DataFrame(pd.read_csv('2lj006.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll7 = pd.DataFrame(pd.read_csv('2lj007.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll8 = pd.DataFrame(pd.read_csv('2lj008.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll9 = pd.DataFrame(pd.read_csv('2lj009.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll10 = pd.DataFrame(pd.read_csv('2lj010.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll11 = pd.DataFrame(pd.read_csv('2lj011.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll12 = pd.DataFrame(pd.read_csv('2lj012.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll13 = pd.DataFrame(pd.read_csv('2lj013.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll14 = pd.DataFrame(pd.read_csv('2lj014.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll15 = pd.DataFrame(pd.read_csv('2lj015.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll16 = pd.DataFrame(pd.read_csv('2lj016.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll17 = pd.DataFrame(pd.read_csv('2lj017.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll18 = pd.DataFrame(pd.read_csv('2lj018.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll19 = pd.DataFrame(pd.read_csv('2lj019.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll20 = pd.DataFrame(pd.read_csv('2lj020.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll21 = pd.DataFrame(pd.read_csv('2lj021.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll22 = pd.DataFrame(pd.read_csv('2lj022.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll23 = pd.DataFrame(pd.read_csv('2lj023.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll24 = pd.DataFrame(pd.read_csv('2lj024.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll25 = pd.DataFrame(pd.read_csv('2lj025.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll26 = pd.DataFrame(pd.read_csv('2lj026.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll27 = pd.DataFrame(pd.read_csv('2lj027.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll28 = pd.DataFrame(pd.read_csv('2lj028.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll29 = pd.DataFrame(pd.read_csv('2lj029.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll30 = pd.DataFrame(pd.read_csv('2lj030.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll31 = pd.DataFrame(pd.read_csv('2lj031.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll32 = pd.DataFrame(pd.read_csv('2lj032.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll33 = pd.DataFrame(pd.read_csv('2lj033.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll34 = pd.DataFrame(pd.read_csv('2lj034.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll35 = pd.DataFrame(pd.read_csv('2lj035.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll36 = pd.DataFrame(pd.read_csv('2lj036.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll37 = pd.DataFrame(pd.read_csv('2lj037.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll38 = pd.DataFrame(pd.read_csv('2lj038.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll39 = pd.DataFrame(pd.read_csv('2lj039.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll40 = pd.DataFrame(pd.read_csv('2lj040.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll41 = pd.DataFrame(pd.read_csv('2lj041.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll42 = pd.DataFrame(pd.read_csv('2lj042.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll43 = pd.DataFrame(pd.read_csv('2lj043.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll44 = pd.DataFrame(pd.read_csv('2lj044.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll45 = pd.DataFrame(pd.read_csv('2lj045.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll46 = pd.DataFrame(pd.read_csv('2lj046.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll47 = pd.DataFrame(pd.read_csv('2lj047.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll48 = pd.DataFrame(pd.read_csv('2lj048.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll49 = pd.DataFrame(pd.read_csv('2lj049.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll50 = pd.DataFrame(pd.read_csv('2lj050.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll51 = pd.DataFrame(pd.read_csv("2lj051.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll52 = pd.DataFrame(pd.read_csv("2lj052.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll53 = pd.DataFrame(pd.read_csv("2lj053.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll54 = pd.DataFrame(pd.read_csv("2lj054.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll55 = pd.DataFrame(pd.read_csv("2lj055.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll56 = pd.DataFrame(pd.read_csv("2lj056.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll57 = pd.DataFrame(pd.read_csv("2lj057.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll58 = pd.DataFrame(pd.read_csv("2lj058.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll59 = pd.DataFrame(pd.read_csv("2lj059.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll60 = pd.DataFrame(pd.read_csv("2lj060.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll61 = pd.DataFrame(pd.read_csv("2lj061.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll62 = pd.DataFrame(pd.read_csv("2lj062.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll63 = pd.DataFrame(pd.read_csv("2lj063.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll64 = pd.DataFrame(pd.read_csv("2lj064.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll65 = pd.DataFrame(pd.read_csv("2lj065.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll66 = pd.DataFrame(pd.read_csv("2lj066.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll67 = pd.DataFrame(pd.read_csv("2lj067.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll68 = pd.DataFrame(pd.read_csv("2lj068.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll69 = pd.DataFrame(pd.read_csv("2lj069.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll70 = pd.DataFrame(pd.read_csv("2lj070.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll71 = pd.DataFrame(pd.read_csv("2lj071.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll72 = pd.DataFrame(pd.read_csv("2lj072.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll73 = pd.DataFrame(pd.read_csv("2lj073.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll74 = pd.DataFrame(pd.read_csv("2lj074.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll75 = pd.DataFrame(pd.read_csv("2lj075.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll76 = pd.DataFrame(pd.read_csv("2lj076.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll77 = pd.DataFrame(pd.read_csv("2lj077.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll78 = pd.DataFrame(pd.read_csv("2lj078.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll79 = pd.DataFrame(pd.read_csv("2lj079.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll80 = pd.DataFrame(pd.read_csv("2lj080.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll81 = pd.DataFrame(pd.read_csv("2lj081.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll82 = pd.DataFrame(pd.read_csv("2lj082.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll83 = pd.DataFrame(pd.read_csv("2lj083.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll84 = pd.DataFrame(pd.read_csv("2lj084.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll85 = pd.DataFrame(pd.read_csv("2lj085.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll86 = pd.DataFrame(pd.read_csv("2lj086.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll87 = pd.DataFrame(pd.read_csv("2lj087.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll88 = pd.DataFrame(pd.read_csv("2lj088.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll89 = pd.DataFrame(pd.read_csv("2lj089.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll90 = pd.DataFrame(pd.read_csv("2lj090.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll91 = pd.DataFrame(pd.read_csv("2lj091.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll92 = pd.DataFrame(pd.read_csv("2lj092.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll93 = pd.DataFrame(pd.read_csv("2lj093.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll94 = pd.DataFrame(pd.read_csv("2lj094.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll95 = pd.DataFrame(pd.read_csv("2lj095.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll96 = pd.DataFrame(pd.read_csv("2lj096.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll97 = pd.DataFrame(pd.read_csv("2lj097.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll98 = pd.DataFrame(pd.read_csv("2lj098.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll99 = pd.DataFrame(pd.read_csv("2lj099.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfll100 = pd.DataFrame(pd.read_csv("2lj100.dat", skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))

# %%
#Arreglo de los DataFrames.
dflln = [dfll1,dfll2,dfll3,dfll4,dfll5,dfll6,dfll7,dfll8,dfll9,dfll10,dfll11,dfll12,dfll13,dfll14,dfll15,dfll16,dfll17,dfll18,dfll19,dfll20,dfll21,dfll22,dfll23,dfll24,dfll25,dfll26,dfll27,dfll28,dfll29,dfll30,dfll31,dfll32,dfll33,dfll34,dfll35,dfll36,dfll37,dfll38,dfll39,dfll40,dfll41,dfll42,dfll43,dfll44,dfll45,dfll46,dfll47,dfll48,dfll49,dfll50,dfll51,dfll52,dfll53,dfll54,dfll55,dfll56,dfll57,dfll58,dfll59,dfll60,dfll61,dfll62,dfll63,dfll64,dfll65,dfll66,dfll67,dfll68,dfll69,dfll70,dfll71,dfll72,dfll73,dfll74,dfll75,dfll76,dfll77,dfll78,dfll79,dfll80,dfll81,dfll82,dfll83,dfll84,dfll85,dfll86,dfll87,dfll88,dfll89,dfll90,dfll91,dfll92,dfll93,dfll94,dfll95,dfll96,dfll97,dfll98,dfll99,dfll100]

# %%
#Se toma el último dato de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dflln[i].X.iloc[99]
    y = dflln[i].Y.iloc[99]
    datx.append(x)
    daty.append(y)
dfllLast = pd.DataFrame({"X" : datx, "Y" : daty})
dfllLast.index = np.arange(1, 101)
#dfllLast

# %%
#Descripción de Datos.
dfllLast.describe()
# Out:
#                 X           Y
# count  100.000000  100.000000
# mean     0.267438    9.639176
# std      8.979562    2.306931
# min    -15.607531    4.326316
# 25%     -6.847630    7.893512
# 50%      0.378795    9.666539
# 75%      8.133404   11.495468
# max     15.457147   13.640148

# %%
#Boxplot para los últimos datos.
dfllLast.plot.box(grid=True,color='purple')

# %%
#Histograma con "bins" columnas.
hist = dfllLast.hist(bins=40, color='purple')

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfllLast
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.867, p=0.000
# La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)

# %%
plt.figure(figsize=(10, 10))
plt.plot(dfll56["X"], dfll56["Y"], marker=".", color="purple")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (2)")
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.plot(dfll30["X"], dfll30["Y"], marker=".", color="purple")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (2)")
plt.show()

# %%
#Graficamos el movimiento de las 100 partículas bajo el potencial de Lenard Jones (2).
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfll1["X"], dfll1["Y"], marker=".")
plt.plot(dfll2["X"], dfll2["Y"], marker=".")
plt.plot(dfll3["X"], dfll3["Y"], marker=".")
plt.plot(dfll4["X"], dfll4["Y"], marker=".")
plt.plot(dfll5["X"], dfll5["Y"], marker=".")
plt.plot(dfll6["X"], dfll6["Y"], marker=".")
plt.plot(dfll7["X"], dfll7["Y"], marker=".")
plt.plot(dfll8["X"], dfll8["Y"], marker=".")
plt.plot(dfll9["X"], dfll9["Y"], marker=".")
plt.plot(dfll10["X"], dfll10["Y"], marker=".")
plt.plot(dfll11["X"], dfll11["Y"], marker=".")
plt.plot(dfll12["X"], dfll12["Y"], marker=".")
plt.plot(dfll13["X"], dfll13["Y"], marker=".")
plt.plot(dfll14["X"], dfll14["Y"], marker=".")
plt.plot(dfll15["X"], dfll15["Y"], marker=".")
plt.plot(dfll16["X"], dfll16["Y"], marker=".")
plt.plot(dfll17["X"], dfll17["Y"], marker=".")
plt.plot(dfll18["X"], dfll18["Y"], marker=".")
plt.plot(dfll19["X"], dfll19["Y"], marker=".")
plt.plot(dfll20["X"], dfll20["Y"], marker=".")
plt.plot(dfll21["X"], dfll21["Y"], marker=".")
plt.plot(dfll22["X"], dfll22["Y"], marker=".")
plt.plot(dfll23["X"], dfll23["Y"], marker=".")
plt.plot(dfll24["X"], dfll24["Y"], marker=".")
plt.plot(dfll25["X"], dfll25["Y"], marker=".")
plt.plot(dfll26["X"], dfll26["Y"], marker=".")
plt.plot(dfll27["X"], dfll27["Y"], marker=".")
plt.plot(dfll28["X"], dfll28["Y"], marker=".")
plt.plot(dfll29["X"], dfll29["Y"], marker=".")
plt.plot(dfll30["X"], dfll30["Y"], marker=".")
plt.plot(dfll31["X"], dfll31["Y"], marker=".")
plt.plot(dfll32["X"], dfll32["Y"], marker=".")
plt.plot(dfll33["X"], dfll33["Y"], marker=".")
plt.plot(dfll34["X"], dfll34["Y"], marker=".")
plt.plot(dfll35["X"], dfll35["Y"], marker=".")
plt.plot(dfll36["X"], dfll36["Y"], marker=".")
plt.plot(dfll37["X"], dfll37["Y"], marker=".")
plt.plot(dfll38["X"], dfll38["Y"], marker=".")
plt.plot(dfll39["X"], dfll39["Y"], marker=".")
plt.plot(dfll40["X"], dfll40["Y"], marker=".")
plt.plot(dfll41["X"], dfll41["Y"], marker=".")
plt.plot(dfll42["X"], dfll42["Y"], marker=".")
plt.plot(dfll43["X"], dfll43["Y"], marker=".")
plt.plot(dfll44["X"], dfll44["Y"], marker=".")
plt.plot(dfll45["X"], dfll45["Y"], marker=".")
plt.plot(dfll46["X"], dfll46["Y"], marker=".")
plt.plot(dfll47["X"], dfll47["Y"], marker=".")
plt.plot(dfll48["X"], dfll48["Y"], marker=".")
plt.plot(dfll49["X"], dfll49["Y"], marker=".")
plt.plot(dfll50["X"], dfll50["Y"], marker=".")
plt.plot(dfll51["X"], dfll51["Y"], marker=".")
plt.plot(dfll52["X"], dfll52["Y"], marker=".")
plt.plot(dfll53["X"], dfll53["Y"], marker=".")
plt.plot(dfll54["X"], dfll54["Y"], marker=".")
plt.plot(dfll55["X"], dfll55["Y"], marker=".")
plt.plot(dfll56["X"], dfll56["Y"], marker=".")
plt.plot(dfll57["X"], dfll57["Y"], marker=".")
plt.plot(dfll58["X"], dfll58["Y"], marker=".")
plt.plot(dfll59["X"], dfll59["Y"], marker=".")
plt.plot(dfll60["X"], dfll60["Y"], marker=".")
plt.plot(dfll61["X"], dfll61["Y"], marker=".")
plt.plot(dfll62["X"], dfll62["Y"], marker=".")
plt.plot(dfll63["X"], dfll63["Y"], marker=".")
plt.plot(dfll64["X"], dfll64["Y"], marker=".")
plt.plot(dfll65["X"], dfll65["Y"], marker=".")
plt.plot(dfll66["X"], dfll66["Y"], marker=".")
plt.plot(dfll67["X"], dfll67["Y"], marker=".")
plt.plot(dfll68["X"], dfll68["Y"], marker=".")
plt.plot(dfll69["X"], dfll69["Y"], marker=".")
plt.plot(dfll70["X"], dfll70["Y"], marker=".")
plt.plot(dfll71["X"], dfll71["Y"], marker=".")
plt.plot(dfll72["X"], dfll72["Y"], marker=".")
plt.plot(dfll73["X"], dfll73["Y"], marker=".")
plt.plot(dfll74["X"], dfll74["Y"], marker=".")
plt.plot(dfll75["X"], dfll75["Y"], marker=".")
plt.plot(dfll76["X"], dfll76["Y"], marker=".")
plt.plot(dfll77["X"], dfll77["Y"], marker=".")
plt.plot(dfll78["X"], dfll78["Y"], marker=".")
plt.plot(dfll79["X"], dfll79["Y"], marker=".")
plt.plot(dfll80["X"], dfll80["Y"], marker=".")
plt.plot(dfll81["X"], dfll81["Y"], marker=".")
plt.plot(dfll82["X"], dfll82["Y"], marker=".")
plt.plot(dfll83["X"], dfll83["Y"], marker=".")
plt.plot(dfll84["X"], dfll84["Y"], marker=".")
plt.plot(dfll85["X"], dfll85["Y"], marker=".")
plt.plot(dfll86["X"], dfll86["Y"], marker=".")
plt.plot(dfll87["X"], dfll87["Y"], marker=".")
plt.plot(dfll88["X"], dfll88["Y"], marker=".")
plt.plot(dfll89["X"], dfll89["Y"], marker=".")
plt.plot(dfll90["X"], dfll90["Y"], marker=".")
plt.plot(dfll91["X"], dfll91["Y"], marker=".")
plt.plot(dfll92["X"], dfll92["Y"], marker=".")
plt.plot(dfll93["X"], dfll93["Y"], marker=".")
plt.plot(dfll94["X"], dfll94["Y"], marker=".")
plt.plot(dfll95["X"], dfll95["Y"], marker=".")
plt.plot(dfll96["X"], dfll96["Y"], marker=".")
plt.plot(dfll97["X"], dfll97["Y"], marker=".")
plt.plot(dfll98["X"], dfll98["Y"], marker=".")
plt.plot(dfll99["X"], dfll99["Y"], marker=".")
plt.plot(dfll100["X"], dfll100["Y"], marker=".")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (2)")
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **LENNARD JONES 1B**
#
#  Número de Átomos                 400
#
#  Número de Ciclos               100100
#
#  Frecuencia de Escritura          100
#
#  Frecuencia de Resguardo            1
#
#  Frecuencia de Despl.              10
#
#  Radio de Corte del Pot.      15.8114
#
#  Densidad Reducida             0.4000
#
#  Frac. en Vol.                 0.3142
#
#  Temperatura                   1.5000

# %%
#Leemos cada archivo de datos con el potencial de Lenard Jones (LJ1B) y 
#los almacenamos, cada uno, en un DataFrame. 
#Se usa Skiprows de -1 para dejar pasar un espacio y nombrar a las columnas "x" y "y".
dfbl1 = pd.DataFrame(pd.read_csv('2bl001.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl2 = pd.DataFrame(pd.read_csv('2bl002.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl3 = pd.DataFrame(pd.read_csv('2bl003.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl4 = pd.DataFrame(pd.read_csv('2bl004.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl5 = pd.DataFrame(pd.read_csv('2bl005.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl6 = pd.DataFrame(pd.read_csv('2bl006.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl7 = pd.DataFrame(pd.read_csv('2bl007.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl8 = pd.DataFrame(pd.read_csv('2bl008.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl9 = pd.DataFrame(pd.read_csv('2bl009.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl10 = pd.DataFrame(pd.read_csv('2bl010.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl11 = pd.DataFrame(pd.read_csv('2bl011.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl12 = pd.DataFrame(pd.read_csv('2bl012.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl13 = pd.DataFrame(pd.read_csv('2bl013.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl14 = pd.DataFrame(pd.read_csv('2bl014.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl15 = pd.DataFrame(pd.read_csv('2bl015.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl16 = pd.DataFrame(pd.read_csv('2bl016.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl17 = pd.DataFrame(pd.read_csv('2bl017.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl18 = pd.DataFrame(pd.read_csv('2bl018.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl19 = pd.DataFrame(pd.read_csv('2bl019.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl20 = pd.DataFrame(pd.read_csv('2bl020.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl21 = pd.DataFrame(pd.read_csv('2bl021.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl22 = pd.DataFrame(pd.read_csv('2bl022.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl23 = pd.DataFrame(pd.read_csv('2bl023.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl24 = pd.DataFrame(pd.read_csv('2bl024.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl25 = pd.DataFrame(pd.read_csv('2bl025.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl26 = pd.DataFrame(pd.read_csv('2bl026.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl27 = pd.DataFrame(pd.read_csv('2bl027.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl28 = pd.DataFrame(pd.read_csv('2bl028.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl29 = pd.DataFrame(pd.read_csv('2bl029.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl30 = pd.DataFrame(pd.read_csv('2bl030.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl31 = pd.DataFrame(pd.read_csv('2bl031.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl32 = pd.DataFrame(pd.read_csv('2bl032.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl33 = pd.DataFrame(pd.read_csv('2bl033.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl34 = pd.DataFrame(pd.read_csv('2bl034.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl35 = pd.DataFrame(pd.read_csv('2bl035.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl36 = pd.DataFrame(pd.read_csv('2bl036.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl37 = pd.DataFrame(pd.read_csv('2bl037.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl38 = pd.DataFrame(pd.read_csv('2bl038.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl39 = pd.DataFrame(pd.read_csv('2bl039.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl40 = pd.DataFrame(pd.read_csv('2bl040.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl41 = pd.DataFrame(pd.read_csv('2bl041.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl42 = pd.DataFrame(pd.read_csv('2bl042.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl43 = pd.DataFrame(pd.read_csv('2bl043.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl44 = pd.DataFrame(pd.read_csv('2bl044.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl45 = pd.DataFrame(pd.read_csv('2bl045.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl46 = pd.DataFrame(pd.read_csv('2bl046.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl47 = pd.DataFrame(pd.read_csv('2bl047.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl48 = pd.DataFrame(pd.read_csv('2bl048.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl49 = pd.DataFrame(pd.read_csv('2bl049.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl50 = pd.DataFrame(pd.read_csv('2bl050.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl51 = pd.DataFrame(pd.read_csv('2bl051.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl52 = pd.DataFrame(pd.read_csv('2bl052.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl53 = pd.DataFrame(pd.read_csv('2bl053.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl54 = pd.DataFrame(pd.read_csv('2bl054.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl55 = pd.DataFrame(pd.read_csv('2bl055.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl56 = pd.DataFrame(pd.read_csv('2bl056.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl57 = pd.DataFrame(pd.read_csv('2bl057.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl58 = pd.DataFrame(pd.read_csv('2bl058.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl59 = pd.DataFrame(pd.read_csv('2bl059.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl60 = pd.DataFrame(pd.read_csv('2bl060.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl61 = pd.DataFrame(pd.read_csv('2bl061.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl62 = pd.DataFrame(pd.read_csv('2bl062.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl63 = pd.DataFrame(pd.read_csv('2bl063.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl64 = pd.DataFrame(pd.read_csv('2bl064.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl65 = pd.DataFrame(pd.read_csv('2bl065.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl66 = pd.DataFrame(pd.read_csv('2bl066.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl67 = pd.DataFrame(pd.read_csv('2bl067.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl68 = pd.DataFrame(pd.read_csv('2bl068.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl69 = pd.DataFrame(pd.read_csv('2bl069.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl70 = pd.DataFrame(pd.read_csv('2bl070.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl71 = pd.DataFrame(pd.read_csv('2bl071.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl72 = pd.DataFrame(pd.read_csv('2bl072.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl73 = pd.DataFrame(pd.read_csv('2bl073.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl74 = pd.DataFrame(pd.read_csv('2bl074.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl75 = pd.DataFrame(pd.read_csv('2bl075.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl76 = pd.DataFrame(pd.read_csv('2bl076.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl77 = pd.DataFrame(pd.read_csv('2bl077.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl78 = pd.DataFrame(pd.read_csv('2bl078.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl79 = pd.DataFrame(pd.read_csv('2bl079.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl80 = pd.DataFrame(pd.read_csv('2bl080.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl81 = pd.DataFrame(pd.read_csv('2bl081.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl82 = pd.DataFrame(pd.read_csv('2bl082.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl83 = pd.DataFrame(pd.read_csv('2bl083.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl84 = pd.DataFrame(pd.read_csv('2bl084.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl85 = pd.DataFrame(pd.read_csv('2bl085.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl86 = pd.DataFrame(pd.read_csv('2bl086.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl87 = pd.DataFrame(pd.read_csv('2bl087.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl88 = pd.DataFrame(pd.read_csv('2bl088.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl89 = pd.DataFrame(pd.read_csv('2bl089.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl90 = pd.DataFrame(pd.read_csv('2bl090.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl91 = pd.DataFrame(pd.read_csv('2bl091.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl92 = pd.DataFrame(pd.read_csv('2bl092.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl93 = pd.DataFrame(pd.read_csv('2bl093.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl94 = pd.DataFrame(pd.read_csv('2bl094.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl95 = pd.DataFrame(pd.read_csv('2bl095.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl96 = pd.DataFrame(pd.read_csv('2bl096.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl97 = pd.DataFrame(pd.read_csv('2bl097.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl98 = pd.DataFrame(pd.read_csv('2bl098.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl99 = pd.DataFrame(pd.read_csv('2bl099.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbl100 = pd.DataFrame(pd.read_csv('2bl100.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))

# %%
#Arreglos de los Data Frames.
dfbln = [dfbl1,dfbl2,dfbl3,dfbl4,dfbl5,dfbl6,dfbl7,dfbl8,dfbl9,dfbl10,dfbl11,dfbl12,dfbl13,dfbl14,dfbl15,dfbl16,dfbl17,dfbl18,dfbl19,dfbl20,dfbl21,dfbl22,dfbl23,dfbl24,dfbl25,dfbl26,dfbl27,dfbl28,dfbl29,dfbl30,dfbl31,dfbl32,dfbl33,dfbl34,dfbl35,dfbl36,dfbl37,dfbl38,dfbl39,dfbl40,dfbl41,dfbl42,dfbl43,dfbl44,dfbl45,dfbl46,dfbl47,dfbl48,dfbl49,dfbl50,dfbl51,dfbl52,dfbl53,dfbl54,dfbl55,dfbl56,dfbl57,dfbl58,dfbl59,dfbl60,dfbl61,dfbl62,dfbl63,dfbl64,dfbl65,dfbl66,dfbl67,dfbl68,dfbl69,dfbl70,dfbl71,dfbl72,dfbl73,dfbl74,dfbl75,dfbl76,dfbl77,dfbl78,dfbl79,dfbl80,dfbl81,dfbl82,dfbl83,dfbl84,dfbl85,dfbl86,dfbl87,dfbl88,dfbl89,dfbl90,dfbl91,dfbl92,dfbl93,dfbl94,dfbl95,dfbl96,dfbl97,dfbl98,dfbl99,dfbl100]

# %%
#Se toma el último dato de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dfbln[i].X.iloc[99]
    y = dfbln[i].Y.iloc[99]
    datx.append(x)
    daty.append(y)
dfblLast = pd.DataFrame({"X" : datx, "Y" : daty})
dfblLast.index = np.arange(1, 101)
#dfblLast

# %%
#Descripción de Datos.
dfblLast.describe()
# Out:
#                 X           Y
# count  100.000000  100.000000
# mean    -0.358156    5.308097
# std      8.926763    2.581244
# min    -15.692847   -0.532195
# 25%     -8.603135    3.527370
# 50%     -0.151032    5.615548
# 75%      6.885035    7.109174
# max     15.457147   10.943350

# %%
#Boxplot para los últimos datos.
dfblLast.plot.box(grid=True,color='cyan')

# %%
#Histograma con "bins" columnas.
hist = dfblLast.hist(bins=40, color='cyan')

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfblLast
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.918, p=0.000
# La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)

# %%
plt.figure(figsize=(10, 10))
plt.plot(dfbl50["X"], dfbl50["Y"], marker=".", color = "cyan")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (1B)")
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.plot(dfbl97["X"], dfbl97["Y"], marker=".", color = "cyan")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (1B)")
plt.show()

# %%
#Graficamos el movimiento de las 100 partículas bajo el potencial de Lenard Jones (1B).
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfbl1["X"], dfbl1["Y"], marker=".")
plt.plot(dfbl2["X"], dfbl2["Y"], marker=".")
plt.plot(dfbl3["X"], dfbl3["Y"], marker=".")
plt.plot(dfbl4["X"], dfbl4["Y"], marker=".")
plt.plot(dfbl5["X"], dfbl5["Y"], marker=".")
plt.plot(dfbl6["X"], dfbl6["Y"], marker=".")
plt.plot(dfbl7["X"], dfbl7["Y"], marker=".")
plt.plot(dfbl8["X"], dfbl8["Y"], marker=".")
plt.plot(dfbl9["X"], dfbl9["Y"], marker=".")
plt.plot(dfbl10["X"], dfbl10["Y"], marker=".")
plt.plot(dfbl11["X"], dfbl11["Y"], marker=".")
plt.plot(dfbl12["X"], dfbl12["Y"], marker=".")
plt.plot(dfbl13["X"], dfbl13["Y"], marker=".")
plt.plot(dfbl14["X"], dfbl14["Y"], marker=".")
plt.plot(dfbl15["X"], dfbl15["Y"], marker=".")
plt.plot(dfbl16["X"], dfbl16["Y"], marker=".")
plt.plot(dfbl17["X"], dfbl17["Y"], marker=".")
plt.plot(dfbl18["X"], dfbl18["Y"], marker=".")
plt.plot(dfbl19["X"], dfbl19["Y"], marker=".")
plt.plot(dfbl20["X"], dfbl20["Y"], marker=".")
plt.plot(dfbl21["X"], dfbl21["Y"], marker=".")
plt.plot(dfbl22["X"], dfbl22["Y"], marker=".")
plt.plot(dfbl23["X"], dfbl23["Y"], marker=".")
plt.plot(dfbl24["X"], dfbl24["Y"], marker=".")
plt.plot(dfbl25["X"], dfbl25["Y"], marker=".")
plt.plot(dfbl26["X"], dfbl26["Y"], marker=".")
plt.plot(dfbl27["X"], dfbl27["Y"], marker=".")
plt.plot(dfbl28["X"], dfbl28["Y"], marker=".")
plt.plot(dfbl29["X"], dfbl29["Y"], marker=".")
plt.plot(dfbl30["X"], dfbl30["Y"], marker=".")
plt.plot(dfbl31["X"], dfbl31["Y"], marker=".")
plt.plot(dfbl32["X"], dfbl32["Y"], marker=".")
plt.plot(dfbl33["X"], dfbl33["Y"], marker=".")
plt.plot(dfbl34["X"], dfbl34["Y"], marker=".")
plt.plot(dfbl35["X"], dfbl35["Y"], marker=".")
plt.plot(dfbl36["X"], dfbl36["Y"], marker=".")
plt.plot(dfbl37["X"], dfbl37["Y"], marker=".")
plt.plot(dfbl38["X"], dfbl38["Y"], marker=".")
plt.plot(dfbl39["X"], dfbl39["Y"], marker=".")
plt.plot(dfbl40["X"], dfbl40["Y"], marker=".")
plt.plot(dfbl41["X"], dfbl41["Y"], marker=".")
plt.plot(dfbl42["X"], dfbl42["Y"], marker=".")
plt.plot(dfbl43["X"], dfbl43["Y"], marker=".")
plt.plot(dfbl44["X"], dfbl44["Y"], marker=".")
plt.plot(dfbl45["X"], dfbl45["Y"], marker=".")
plt.plot(dfbl46["X"], dfbl64["Y"], marker=".")
plt.plot(dfbl47["X"], dfbl47["Y"], marker=".")
plt.plot(dfbl48["X"], dfbl48["Y"], marker=".")
plt.plot(dfbl49["X"], dfbl49["Y"], marker=".")
plt.plot(dfbl50["X"], dfbl50["Y"], marker=".")
plt.plot(dfbl51["X"], dfbl51["Y"], marker=".")
plt.plot(dfbl52["X"], dfbl52["Y"], marker=".")
plt.plot(dfbl53["X"], dfbl53["Y"], marker=".")
plt.plot(dfbl54["X"], dfbl54["Y"], marker=".")
plt.plot(dfbl55["X"], dfbl55["Y"], marker=".")
plt.plot(dfbl56["X"], dfbl56["Y"], marker=".")
plt.plot(dfbl57["X"], dfbl57["Y"], marker=".")
plt.plot(dfbl58["X"], dfbl58["Y"], marker=".")
plt.plot(dfbl59["X"], dfbl59["Y"], marker=".")
plt.plot(dfbl60["X"], dfbl60["Y"], marker=".")
plt.plot(dfbl61["X"], dfbl61["Y"], marker=".")
plt.plot(dfbl62["X"], dfbl62["Y"], marker=".")
plt.plot(dfbl63["X"], dfbl63["Y"], marker=".")
plt.plot(dfbl64["X"], dfbl64["Y"], marker=".")
plt.plot(dfbl65["X"], dfbl65["Y"], marker=".")
plt.plot(dfbl66["X"], dfbl66["Y"], marker=".")
plt.plot(dfbl67["X"], dfbl67["Y"], marker=".")
plt.plot(dfbl68["X"], dfbl68["Y"], marker=".")
plt.plot(dfbl69["X"], dfbl69["Y"], marker=".")
plt.plot(dfbl70["X"], dfbl70["Y"], marker=".")
plt.plot(dfbl71["X"], dfbl71["Y"], marker=".")
plt.plot(dfbl72["X"], dfbl72["Y"], marker=".")
plt.plot(dfbl73["X"], dfbl73["Y"], marker=".")
plt.plot(dfbl74["X"], dfbl74["Y"], marker=".")
plt.plot(dfbl75["X"], dfbl75["Y"], marker=".")
plt.plot(dfbl76["X"], dfbl76["Y"], marker=".")
plt.plot(dfbl77["X"], dfbl77["Y"], marker=".")
plt.plot(dfbl78["X"], dfbl78["Y"], marker=".")
plt.plot(dfbl79["X"], dfbl79["Y"], marker=".")
plt.plot(dfbl80["X"], dfbl80["Y"], marker=".")
plt.plot(dfbl81["X"], dfbl81["Y"], marker=".")
plt.plot(dfbl82["X"], dfbl82["Y"], marker=".")
plt.plot(dfbl83["X"], dfbl83["Y"], marker=".")
plt.plot(dfbl84["X"], dfbl84["Y"], marker=".")
plt.plot(dfbl85["X"], dfbl85["Y"], marker=".")
plt.plot(dfbl86["X"], dfbl86["Y"], marker=".")
plt.plot(dfbl87["X"], dfbl87["Y"], marker=".")
plt.plot(dfbl88["X"], dfbl88["Y"], marker=".")
plt.plot(dfbl89["X"], dfbl89["Y"], marker=".")
plt.plot(dfbl90["X"], dfbl90["Y"], marker=".")
plt.plot(dfbl91["X"], dfbl91["Y"], marker=".")
plt.plot(dfbl92["X"], dfbl92["Y"], marker=".")
plt.plot(dfbl93["X"], dfbl93["Y"], marker=".")
plt.plot(dfbl94["X"], dfbl94["Y"], marker=".")
plt.plot(dfbl95["X"], dfbl95["Y"], marker=".")
plt.plot(dfbl96["X"], dfbl96["Y"], marker=".")
plt.plot(dfbl97["X"], dfbl97["Y"], marker=".")
plt.plot(dfbl98["X"], dfbl98["Y"], marker=".")
plt.plot(dfbl99["X"], dfbl99["Y"], marker=".")
plt.plot(dfbl100["X"], dfbl100["Y"], marker=".")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (1B)")
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **LENNARD JONES 2B**
#
#  Número de Átomos                 400
#
#  Número de Ciclos               100100
#
#  Frecuencia de Escritura          100
#
#  Frecuencia de Resguardo            1
#
#  Frecuencia de Despl.              10
#
#  Radio de Corte del Pot.      15.8114
#
#  Densidad Reducida             0.4000
#
#  Frac. en Vol.                 0.3142
#
#  Temperatura                   0.7500

# %%
#Leemos cada archivo de datos con el potencial de Lenard Jones (LJ2B) y 
#los almacenamos, cada uno, en un DataFrame. 
#Se usa Skiprows de -1 para dejar pasar un espacio y nombrar a las columnas "x" y "y".
dfbll1 = pd.DataFrame(pd.read_csv('2bll001.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll2 = pd.DataFrame(pd.read_csv('2bll002.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll3 = pd.DataFrame(pd.read_csv('2bll003.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll4 = pd.DataFrame(pd.read_csv('2bll004.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll5 = pd.DataFrame(pd.read_csv('2bll005.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll6 = pd.DataFrame(pd.read_csv('2bll006.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll7 = pd.DataFrame(pd.read_csv('2bll007.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll8 = pd.DataFrame(pd.read_csv('2bll008.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll9 = pd.DataFrame(pd.read_csv('2bll009.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll10 = pd.DataFrame(pd.read_csv('2bll010.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll11 = pd.DataFrame(pd.read_csv('2bll011.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll12 = pd.DataFrame(pd.read_csv('2bll012.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll13 = pd.DataFrame(pd.read_csv('2bll013.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll14 = pd.DataFrame(pd.read_csv('2bll014.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll15 = pd.DataFrame(pd.read_csv('2bll015.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll16 = pd.DataFrame(pd.read_csv('2bll016.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll17 = pd.DataFrame(pd.read_csv('2bll017.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll18 = pd.DataFrame(pd.read_csv('2bll018.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll19 = pd.DataFrame(pd.read_csv('2bll019.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll20 = pd.DataFrame(pd.read_csv('2bll020.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll21 = pd.DataFrame(pd.read_csv('2bll021.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll22 = pd.DataFrame(pd.read_csv('2bll022.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll23 = pd.DataFrame(pd.read_csv('2bll023.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll24 = pd.DataFrame(pd.read_csv('2bll024.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll25 = pd.DataFrame(pd.read_csv('2bll025.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll26 = pd.DataFrame(pd.read_csv('2bll026.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll27 = pd.DataFrame(pd.read_csv('2bll027.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll28 = pd.DataFrame(pd.read_csv('2bll028.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll29 = pd.DataFrame(pd.read_csv('2bll029.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll30 = pd.DataFrame(pd.read_csv('2bll030.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll31 = pd.DataFrame(pd.read_csv('2bll031.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll32 = pd.DataFrame(pd.read_csv('2bll032.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll33 = pd.DataFrame(pd.read_csv('2bll033.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll34 = pd.DataFrame(pd.read_csv('2bll034.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll35 = pd.DataFrame(pd.read_csv('2bll035.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll36 = pd.DataFrame(pd.read_csv('2bll036.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll37 = pd.DataFrame(pd.read_csv('2bll037.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll38 = pd.DataFrame(pd.read_csv('2bll038.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll39 = pd.DataFrame(pd.read_csv('2bll039.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll40 = pd.DataFrame(pd.read_csv('2bll040.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll41 = pd.DataFrame(pd.read_csv('2bll041.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll42 = pd.DataFrame(pd.read_csv('2bll042.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll43 = pd.DataFrame(pd.read_csv('2bll043.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll44 = pd.DataFrame(pd.read_csv('2bll044.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll45 = pd.DataFrame(pd.read_csv('2bll045.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll46 = pd.DataFrame(pd.read_csv('2bll046.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll47 = pd.DataFrame(pd.read_csv('2bll047.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll48 = pd.DataFrame(pd.read_csv('2bll048.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll49 = pd.DataFrame(pd.read_csv('2bll049.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll50 = pd.DataFrame(pd.read_csv('2bll050.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll51 = pd.DataFrame(pd.read_csv('2bll051.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll52 = pd.DataFrame(pd.read_csv('2bll052.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll53 = pd.DataFrame(pd.read_csv('2bll053.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll54 = pd.DataFrame(pd.read_csv('2bll054.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll55 = pd.DataFrame(pd.read_csv('2bll055.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll56 = pd.DataFrame(pd.read_csv('2bll056.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll57 = pd.DataFrame(pd.read_csv('2bll057.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll58 = pd.DataFrame(pd.read_csv('2bll058.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll59 = pd.DataFrame(pd.read_csv('2bll059.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll60 = pd.DataFrame(pd.read_csv('2bll060.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll61 = pd.DataFrame(pd.read_csv('2bll061.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll62 = pd.DataFrame(pd.read_csv('2bll062.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll63 = pd.DataFrame(pd.read_csv('2bll063.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll64 = pd.DataFrame(pd.read_csv('2bll064.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll65 = pd.DataFrame(pd.read_csv('2bll065.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll66 = pd.DataFrame(pd.read_csv('2bll066.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll67 = pd.DataFrame(pd.read_csv('2bll067.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll68 = pd.DataFrame(pd.read_csv('2bll068.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll69 = pd.DataFrame(pd.read_csv('2bll069.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll70 = pd.DataFrame(pd.read_csv('2bll070.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll71 = pd.DataFrame(pd.read_csv('2bll071.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll72 = pd.DataFrame(pd.read_csv('2bll072.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll73 = pd.DataFrame(pd.read_csv('2bll073.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll74 = pd.DataFrame(pd.read_csv('2bll074.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll75 = pd.DataFrame(pd.read_csv('2bll075.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll76 = pd.DataFrame(pd.read_csv('2bll076.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll77 = pd.DataFrame(pd.read_csv('2bll077.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll78 = pd.DataFrame(pd.read_csv('2bll078.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll79 = pd.DataFrame(pd.read_csv('2bll079.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll80 = pd.DataFrame(pd.read_csv('2bll080.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll81 = pd.DataFrame(pd.read_csv('2bll081.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll82 = pd.DataFrame(pd.read_csv('2bll082.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll83 = pd.DataFrame(pd.read_csv('2bll083.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll84 = pd.DataFrame(pd.read_csv('2bll084.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll85 = pd.DataFrame(pd.read_csv('2bll085.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll86 = pd.DataFrame(pd.read_csv('2bll086.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll87 = pd.DataFrame(pd.read_csv('2bll087.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll88 = pd.DataFrame(pd.read_csv('2bll088.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll89 = pd.DataFrame(pd.read_csv('2bll089.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll90 = pd.DataFrame(pd.read_csv('2bll090.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll91 = pd.DataFrame(pd.read_csv('2bll091.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll92 = pd.DataFrame(pd.read_csv('2bll092.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll93 = pd.DataFrame(pd.read_csv('2bll093.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll94 = pd.DataFrame(pd.read_csv('2bll094.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll95 = pd.DataFrame(pd.read_csv('2bll095.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll96 = pd.DataFrame(pd.read_csv('2bll096.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll97 = pd.DataFrame(pd.read_csv('2bll097.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll98 = pd.DataFrame(pd.read_csv('2bll098.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll99 = pd.DataFrame(pd.read_csv('2bll099.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))
dfbll100 = pd.DataFrame(pd.read_csv('2bll100.dat', skiprows=-1, sep='\s+', header=None, names = ["X", "Y"]))

# %%
#Arreglo de los DataFrames
dfblln = [dfbll1,dfbll2,dfbll3,dfbll4,dfbll5,dfbll6,dfbll7,dfbll8,dfbll9,dfbll10,dfbll11,dfbll12,dfbll13,dfbll14,dfbll15,dfbll16,dfbll17,dfbll18,dfbll19,dfbll20,dfbll21,dfbll22,dfbll23,dfbll24,dfbll25,dfbll26,dfbll27,dfbll28,dfbll29,dfbll30,dfbll31,dfbll32,dfbll33,dfbll34,dfbll35,dfbll36,dfbll37,dfbll38,dfbll39,dfbll40,dfbll41,dfbll42,dfbll43,dfbll44,dfbll45,dfbll46,dfbll47,dfbll48,dfbll49,dfbll50,dfbll51,dfbll52,dfbll53,dfbll54,dfbll55,dfbll56,dfbll57,dfbll58,dfbll59,dfbll60,dfbll61,dfbll62,dfbll63,dfbll64,dfbll65,dfbll66,dfbll67,dfbll68,dfbll69,dfbll70,dfbll71,dfbll72,dfbll73,dfbll74,dfbll75,dfbll76,dfbll77,dfbll78,dfbll79,dfbll80,dfbll81,dfbll82,dfbll83,dfbll84,dfbll85,dfbll86,dfbll87,dfbll88,dfbll89,dfbll90,dfbll91,dfbll92,dfbll93,dfbll94,dfbll95,dfbll96,dfbll97,dfbll98,dfbll99,dfbll100]

# %%
#Se toma el último dato de cada DataFrame y se colocan en un nuevo DataFrame.
#Se emplea un for.

datx = []
daty = []
for i in range (0, 100):
    x = dfblln[i].X.iloc[99]
    y = dfblln[i].Y.iloc[99]
    datx.append(x)
    daty.append(y)
dfbllLast = pd.DataFrame({"X" : datx, "Y" : daty})
dfbllLast.index = np.arange(1, 101)
#dfbllLast

# %%
#Descripción de Datos
dfbllLast.describe()
# Out:
#                 X           Y
# count  100.000000  100.000000
# mean     0.032127    5.401061
# std      8.957218    2.461127
# min    -14.934498    0.159243
# 25%     -8.091054    3.626781
# 50%      0.306698    5.728570
# 75%      7.797428    7.092345
# max     15.368339   10.230510

# %%
#Boxplot para los últimos datos.
dfbllLast.plot.box(grid=True,color='pink')

# %%
#Histograma con "bins" columnas.
hist = dfbllLast.hist(bins=40, color='pink')

# %%
#Prueba Shapiro-Wilk.
#Probar si los datos siguen una distribución Gaussiana.
#Se parte de desconocer el tipo de distribución de los datos.
#Se asume que las observaciones en cada muestra son independientes e idénticamente distribuídas.
#Hipótesis Nula y Alternativa:
#H0 = La muestra sigue una Distribución Gaussiana.
#H1 = La muestra no sigue una Distribución Gaussiana.

from scipy.stats import shapiro
data = dfbllLast
stat, p = shapiro(data)
#Estadístico de Prueba y P-valor.
print('Estadístico de Prueba=%.3f, p=%.3f' % (stat, p))

#Interpretación
#Nivel de significancia:
alpha = 0.05
if p > alpha:
	print('La muestra parece seguir una Distribución Gaussiana (no se rechaza H0)')
else:
	print('La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)')
# Out:
# Estadístico de Prueba=0.916, p=0.000
# La muestra, al parecer, no sigue una Distribución Gaussiana (se rechaza H0)

# %%
plt.figure(figsize=(10, 10))
plt.plot(dfbll27["X"], dfbll27["Y"], marker=".", color = "pink")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (2B)")
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.plot(dfbll78["X"], dfbll78["Y"], marker=".", color = "pink")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (2B)")
plt.show()

# %%
#Graficamos el movimiento de las 100 partículas bajo el potencial de Lenard Jones (2B).
plt.figure(figsize=(10, 10))
#Marcamos la trayectoria con puntos.
plt.plot(dfbll1["X"], dfbll1["Y"], marker=".")
plt.plot(dfbll2["X"], dfbll2["Y"], marker=".")
plt.plot(dfbll3["X"], dfbll3["Y"], marker=".")
plt.plot(dfbll4["X"], dfbll4["Y"], marker=".")
plt.plot(dfbll5["X"], dfbll5["Y"], marker=".")
plt.plot(dfbll6["X"], dfbll6["Y"], marker=".")
plt.plot(dfbll7["X"], dfbll7["Y"], marker=".")
plt.plot(dfbll8["X"], dfbll8["Y"], marker=".")
plt.plot(dfbll9["X"], dfbll9["Y"], marker=".")
plt.plot(dfbll10["X"], dfbll10["Y"], marker=".")
plt.plot(dfbll11["X"], dfbll11["Y"], marker=".")
plt.plot(dfbll12["X"], dfbll12["Y"], marker=".")
plt.plot(dfbll13["X"], dfbll13["Y"], marker=".")
plt.plot(dfbll14["X"], dfbll14["Y"], marker=".")
plt.plot(dfbll15["X"], dfbl15["Y"], marker=".")
plt.plot(dfbll16["X"], dfbll16["Y"], marker=".")
plt.plot(dfbll17["X"], dfbll17["Y"], marker=".")
plt.plot(dfbll18["X"], dfbll18["Y"], marker=".")
plt.plot(dfbll19["X"], dfbll19["Y"], marker=".")
plt.plot(dfbll20["X"], dfbll20["Y"], marker=".")
plt.plot(dfbll21["X"], dfbll21["Y"], marker=".")
plt.plot(dfbll22["X"], dfbll22["Y"], marker=".")
plt.plot(dfbll23["X"], dfbll23["Y"], marker=".")
plt.plot(dfbll24["X"], dfbll24["Y"], marker=".")
plt.plot(dfbll25["X"], dfbll25["Y"], marker=".")
plt.plot(dfbll26["X"], dfbll26["Y"], marker=".")
plt.plot(dfbll27["X"], dfbll27["Y"], marker=".")
plt.plot(dfbll28["X"], dfbll28["Y"], marker=".")
plt.plot(dfbll29["X"], dfbll29["Y"], marker=".")
plt.plot(dfbll30["X"], dfbll30["Y"], marker=".")
plt.plot(dfbll31["X"], dfbll31["Y"], marker=".")
plt.plot(dfbll32["X"], dfbll32["Y"], marker=".")
plt.plot(dfbll33["X"], dfbll33["Y"], marker=".")
plt.plot(dfbll34["X"], dfbll34["Y"], marker=".")
plt.plot(dfbll35["X"], dfbll35["Y"], marker=".")
plt.plot(dfbll36["X"], dfbll36["Y"], marker=".")
plt.plot(dfbll37["X"], dfbll37["Y"], marker=".")
plt.plot(dfbll38["X"], dfbll38["Y"], marker=".")
plt.plot(dfbll39["X"], dfbll39["Y"], marker=".")
plt.plot(dfbll40["X"], dfbll40["Y"], marker=".")
plt.plot(dfbll41["X"], dfbll41["Y"], marker=".")
plt.plot(dfbll42["X"], dfbll42["Y"], marker=".")
plt.plot(dfbll43["X"], dfbll43["Y"], marker=".")
plt.plot(dfbll44["X"], dfbll44["Y"], marker=".")
plt.plot(dfbll45["X"], dfbll45["Y"], marker=".")
plt.plot(dfbll46["X"], dfbll64["Y"], marker=".")
plt.plot(dfbll47["X"], dfbll47["Y"], marker=".")
plt.plot(dfbll48["X"], dfbll48["Y"], marker=".")
plt.plot(dfbll49["X"], dfbll49["Y"], marker=".")
plt.plot(dfbll50["X"], dfbll50["Y"], marker=".")
plt.plot(dfbll51["X"], dfbll51["Y"], marker=".")
plt.plot(dfbll52["X"], dfbll52["Y"], marker=".")
plt.plot(dfbll53["X"], dfbll53["Y"], marker=".")
plt.plot(dfbll54["X"], dfbll54["Y"], marker=".")
plt.plot(dfbll55["X"], dfbll55["Y"], marker=".")
plt.plot(dfbll56["X"], dfbll56["Y"], marker=".")
plt.plot(dfbll57["X"], dfbll57["Y"], marker=".")
plt.plot(dfbll58["X"], dfbll58["Y"], marker=".")
plt.plot(dfbll59["X"], dfbll59["Y"], marker=".")
plt.plot(dfbll60["X"], dfbll60["Y"], marker=".")
plt.plot(dfbll61["X"], dfbll61["Y"], marker=".")
plt.plot(dfbll62["X"], dfbll62["Y"], marker=".")
plt.plot(dfbll63["X"], dfbll63["Y"], marker=".")
plt.plot(dfbll64["X"], dfbll64["Y"], marker=".")
plt.plot(dfbll65["X"], dfbll65["Y"], marker=".")
plt.plot(dfbll66["X"], dfbll66["Y"], marker=".")
plt.plot(dfbll67["X"], dfbll67["Y"], marker=".")
plt.plot(dfbll68["X"], dfbll68["Y"], marker=".")
plt.plot(dfbll69["X"], dfbll69["Y"], marker=".")
plt.plot(dfbll70["X"], dfbll70["Y"], marker=".")
plt.plot(dfbll71["X"], dfbll71["Y"], marker=".")
plt.plot(dfbll72["X"], dfbll72["Y"], marker=".")
plt.plot(dfbll73["X"], dfbll73["Y"], marker=".")
plt.plot(dfbll74["X"], dfbll74["Y"], marker=".")
plt.plot(dfbll75["X"], dfbll75["Y"], marker=".")
plt.plot(dfbll76["X"], dfbll76["Y"], marker=".")
plt.plot(dfbll77["X"], dfbll77["Y"], marker=".")
plt.plot(dfbll78["X"], dfbll78["Y"], marker=".")
plt.plot(dfbll79["X"], dfbll79["Y"], marker=".")
plt.plot(dfbll80["X"], dfbll80["Y"], marker=".")
plt.plot(dfbll81["X"], dfbll81["Y"], marker=".")
plt.plot(dfbll82["X"], dfbll82["Y"], marker=".")
plt.plot(dfbll83["X"], dfbll83["Y"], marker=".")
plt.plot(dfbll84["X"], dfbll84["Y"], marker=".")
plt.plot(dfbll85["X"], dfbll85["Y"], marker=".")
plt.plot(dfbll86["X"], dfbll86["Y"], marker=".")
plt.plot(dfbll87["X"], dfbll87["Y"], marker=".")
plt.plot(dfbll88["X"], dfbll88["Y"], marker=".")
plt.plot(dfbll89["X"], dfbll89["Y"], marker=".")
plt.plot(dfbll90["X"], dfbll90["Y"], marker=".")
plt.plot(dfbll91["X"], dfbll91["Y"], marker=".")
plt.plot(dfbll92["X"], dfbll92["Y"], marker=".")
plt.plot(dfbll93["X"], dfbll93["Y"], marker=".")
plt.plot(dfbll94["X"], dfbll94["Y"], marker=".")
plt.plot(dfbll95["X"], dfbll95["Y"], marker=".")
plt.plot(dfbll96["X"], dfbll96["Y"], marker=".")
plt.plot(dfbll97["X"], dfbll97["Y"], marker=".")
plt.plot(dfbll98["X"], dfbll98["Y"], marker=".")
plt.plot(dfbll99["X"], dfbll99["Y"], marker=".")
plt.plot(dfbll100["X"], dfbll100["Y"], marker=".")
plt.grid(True)
#plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title("Potencial Lenard Jones (2B)")
plt.show()
